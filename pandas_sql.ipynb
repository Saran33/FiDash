# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy.orm import sessionmaker, Session
from sqlalchemy import create_engine, select, asc, desc, func
import logging
import time
from TickerScrape.models import Security, AssetClass, Country, Currency, Industry, Exchange, Tag

# %%
# uri = 'sqlite:///databases/TickerScrape.db'
uri = 'sqlite:////Users/zenman618/Documents/git_packages/VisualStudioGit/TickerScrape/sqlite_files/TickerScrape.db'

# %%
# df = pd.read_sql_table("security", uri, schema=None, index_col='id', coerce_float=True, chunksize=None, columns=['ticker, name']) # columns=['ticker, name'], parse_dates='Inception_date',
# df.head()

# %%
def init_engine(uri):
    logging.basicConfig()
    logging.getLogger('sqlalchemy.engine').setLevel(logging.INFO)
    engine = create_engine(uri)
    return engine

def db_connect(engine):
    connection = engine.connect()
    logging.info("****_Ticker_Pipeline: database connected****")
    return connection

def db_session(engine):
    # Session = sessionmaker(bind=engine)
    # session = Session()
    session = Session(engine)
    logging.info("****_Ticker_Pipeline: database connected****")
    return session

# %%
engine = init_engine(uri)

# %%
# %%timeit
with db_connect(engine) as con:
    result = con.execute("select ticker from security")
    # for row in result:
    #     print("ticker:", row['ticker'])
    df = pd.DataFrame(result)
df.tail()

# %%
# %%timeit
with db_session(engine) as session:
    result = session.execute("select ticker, name from security")
    df = pd.DataFrame(result, columns = ['Ticker', 'Name'])
df.tail()
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:select ticker, name from security
# INFO:sqlalchemy.engine.Engine:[cached since 103.2s ago] ()
# INFO:sqlalchemy.engine.Engine:ROLLBACK
#       Ticker                       Name
# 80584   TACO  Del Taco Restaurants Inc.
# 80585  PEFDF                  Defli Ltd
# 80586  DNCVF      Defiance Silver Corp.
# 80587  DEFTF     DeFi Technologies Inc.
# 80588   DFTC       Defentect Group Inc.

# %%
# %%timeit
with db_session(engine) as session:
    result = session.execute("select ticker, name from security")
    # print(type(result))
    # for dict_row in result.mappings():
    #     ticker = dict_row['ticker']
    #     name = dict_row['name']
    #     print (dict_row)

    df = pd.DataFrame(result, columns = ['Ticker', 'Name'])
df.tail()
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:select ticker, name from security
# INFO:sqlalchemy.engine.Engine:[cached since 863.2s ago] ()
# INFO:sqlalchemy.engine.Engine:ROLLBACK
#       Ticker                       Name
# 80584   TACO  Del Taco Restaurants Inc.
# 80585  PEFDF                  Defli Ltd
# 80586  DNCVF      Defiance Silver Corp.
# 80587  DEFTF     DeFi Technologies Inc.
# 80588   DFTC       Defentect Group Inc.

# %%
def all_tickers():
    with db_session(engine) as session:
        result = session.execute("select ticker, name from security")
        df = pd.DataFrame(result, columns = ['Ticker', 'Name'])
        df['Label'] = df['Ticker'] + " (" + df['Name'] + ")"
        symbols = df['Ticker']
        labels = df['Label']
    return labels, symbols

labels, symbols = all_tickers()
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:select ticker, name from security
# INFO:sqlalchemy.engine.Engine:[cached since 1468s ago] ()
# INFO:sqlalchemy.engine.Engine:ROLLBACK

# %%
options=[{'label': x, 'value': y} for x, y in zip(labels, symbols)]

options
# Out:
# [{'label': 'ACAZF (Acadian Timber Corp.)', 'value': 'ACAZF'},
#  {'label': 'AKR (Acadia Realty Trust)', 'value': 'AKR'},
#  {'label': 'ACAD (ACADIA Pharmaceuticals Inc.)', 'value': 'ACAD'},
#  {'label': 'ACHC (Acadia Healthcare Co. Inc.)', 'value': 'ACHC'},
#  {'label': 'ASO (Academy Sports & Outdoors Inc.)', 'value': 'ASO'},
#  {'label': 'ACTG (Acacia Research Corp. - Acacia Technologies)',
#   'value': 'ACTG'},
#  {'label': 'ACPGF (Acacia Pharma Group PLC)', 'value': 'ACPGF'},
#  {'label': 'ACCA (Acacia Diversified Holdings Inc.)', 'value': 'ACCA'},
#  {'label': 'ACIU (AC Immune S.A.)', 'value': 'ACIU'},
#  {'label': 'ABVC (ABVC BioPharma Inc.)', 'value': 'ABVC'},
#  {'label': 'AHFI (Absolute Health & Fitness Inc.)', 'value': 'AHFI'},
#  {'label': 'ABST (Absolute Software Corp.)', 'value': 'ABST'},
#  {'label': 'ASCN (Absecon Bancorp)', 'value': 'ASCN'},
#  {'label': 'ABSI (Absci Corp.)', 'value': 'ABSI'},
#  {'label': 'AGRPY (Absa Group Ltd.)', 'value': 'AGRPY'},
#  {'label': 'ASPAW (Abri SPAC I Inc. Wt)', 'value': 'ASPAW'},
#  {'label': 'ATCLF (AdvanceTC Ltd.)', 'value': 'ATCLF'},
#  {'label': 'AVOI (Advanced Voice Recognition Systems Inc.)', 'value': 'AVOI'},
#  {'label': 'APWL (Advanced Powerline Technologies Inc.)', 'value': 'APWL'},
#  {'label': 'AOXY (Advanced Oxygen Technologies Inc.)', 'value': 'AOXY'},
#  {'label': 'AMD (Advanced Micro Devices Inc.)', 'value': 'AMD'},
#  {'label': 'AMPI.WT (Advanced Merger Partners Inc. Wt)', 'value': 'AMPI.WT'},
#  {'label': 'AMPI (Advanced Merger Partners Inc. Cl A)', 'value': 'AMPI'},
#  {'label': 'AMPI.UT (Advanced Merger Partners Inc.)', 'value': 'AMPI.UT'},
#  {'label': 'AVIFY (Advanced Info Service PCL ADR)', 'value': 'AVIFY'},
#  {'label': 'AEIS (Advanced Energy Industries Inc.)', 'value': 'AEIS'},
#  {'label': 'ADES (Advanced Emissions Solutions Inc.)', 'value': 'ADES'},
#  {'label': 'WMS (Advanced Drainage Systems Inc.)', 'value': 'WMS'},
#  {'label': 'ACTX (Advanced Container Technologies Inc.)', 'value': 'ACTX'},
#  {'label': 'ADGCF (Advance Gold Corp.)', 'value': 'ADGCF'},
#  {'label': 'AAP (Advance Auto Parts Inc.)', 'value': 'AAP'},
#  {'label': 'ACTHF (Aduro Clean Technologies Inc.)', 'value': 'ACTHF'},
#  {'label': 'AGSO (AgriSolar Solutions Inc.)', 'value': 'AGSO'},
#  {'label': 'ETPHF (AgriMinco Corp.)', 'value': 'ETPHF'},
#  {'label': 'AGFY (Agrify Corp.)', 'value': 'AGFY'},
#  {'label': 'AGRIW (AgriFORCE Growing Systems Ltd. Wt)', 'value': 'AGRIW'},
#  {'label': 'AGRI (AgriFORCE Growing Systems Ltd.)', 'value': 'AGRI'},
#  {'label': 'AGDY (Agri-Dynamics Inc.)', 'value': 'AGDY'},
#  {'label': 'ACGBY (Agricultural Bank of China Ltd. ADR)', 'value': 'ACGBY'},
#  {'label': 'ACGBF (Agricultural Bank of China Ltd.)', 'value': 'ACGBF'},
#  {'label': 'RICOW (Agrico Acquisition Corp. Wt)', 'value': 'RICOW'},
#  {'label': 'RICO (Agrico Acquisition Corp. Cl A)', 'value': 'RICO'},
#  {'label': 'ADC.PRA (Agree Realty Corp. Dep Pfd. (Rep. 1/1000th 4.250% Perp. Pfd. Series A))',
#   'value': 'ADC.PRA'},
#  {'label': 'ADC (Agree Realty Corp.)', 'value': 'ADC'},
#  {'label': 'AGFAF (Agra Ventures Ltd.)', 'value': 'AGFAF'},
#  {'label': 'API (Agora Inc. ADR)', 'value': 'API'},
#  {'label': 'AEM (Agnico Eagle Mines Ltd.)', 'value': 'AEM'},
#  {'label': 'AGNCM (AGNC Investment Corp. Dep. Pfd. (Rep. 6.875% Cum. Redeem. Pfd. Series D)',
#   'value': 'AGNCM'},
#  {'label': 'ALKEF (Alkane Resources Ltd.)', 'value': 'ALKEF'},
#  {'label': 'ALKT (Alkami Technology Inc.)', 'value': 'ALKT'},
#  {'label': 'ALKM (Alkame Holdings Inc.)', 'value': 'ALKM'},
#  {'label': 'WTER (Alkaline Water Co. Inc.)', 'value': 'WTER'},
#  {'label': 'AKBLF (ALK-Abello A/S Series B)', 'value': 'AKBLF'},
#  {'label': 'AKABY (ALK-Abello A/S ADR)', 'value': 'AKABY'},
#  {'label': 'ALJJ (ALJ Regional Holdings Inc.)', 'value': 'ALJJ'},
#  {'label': 'ALYA (Alithya Group Inc. Cl A)', 'value': 'ALYA'},
#  {'label': 'ALIM (Alimera Sciences Inc.)', 'value': 'ALIM'},
#  {'label': 'ANCUF (Alimentation Couche Tard Inc. Cl B)', 'value': 'ANCUF'},
#  {'label': 'ANCTF (Alimentation Couche Tard Inc. Cl A)', 'value': 'ANCTF'},
#  {'label': 'ALGS (Aligos Therapeutics Inc.)', 'value': 'ALGS'},
#  {'label': 'ALHC (Alignment Healthcare Inc.)', 'value': 'ALHC'},
#  {'label': 'ALGN (Align Technology Inc.)', 'value': 'ALGN'},
#  {'label': 'ALIT.WT (Alight Inc. Wt)', 'value': 'ALIT.WT'},
#  {'label': 'ALIT (Alight Inc.)', 'value': 'ALIT'},
#  {'label': 'AIMC (Altra Industrial Motion Corp.)', 'value': 'AIMC'},
#  {'label': 'ALTO (Alto Ingredients Inc.)', 'value': 'ALTO'},
#  {'label': 'ATUSF (Altius Minerals Corp.)', 'value': 'ATUSF'},
#  {'label': 'ATRWF (Altius Renewable Royalties Corp.)', 'value': 'ATRWF'},
#  {'label': 'ALMFF (Altium Ltd.)', 'value': 'ALMFF'},
#  {'label': 'ALTD (Altitude International Inc.)', 'value': 'ALTD'},
#  {'label': 'ALTUW (Altitude Acquisition Corp. Wt)', 'value': 'ALTUW'},
#  {'label': 'ALTU (Altitude Acquisition Corp. Cl A)', 'value': 'ALTU'},
#  {'label': 'ALTUU (Altitude Acquisition Corp.)', 'value': 'ALTUU'},
#  {'label': 'ASPS (Altisource Portfolio Solutions S.A.)', 'value': 'ASPS'},
#  {'label': 'AAMC (Altisource Asset Management Corp.)', 'value': 'AAMC'},
#  {'label': 'ALTPF (Altiplano Metals Inc.)', 'value': 'ALTPF'},
#  {'label': 'ALT (Altimmune Inc.)', 'value': 'ALT'},
#  {'label': 'AGCWW (Altimeter Growth Corp. Wt)', 'value': 'AGCWW'},
#  {'label': 'AGC (Altimeter Growth Corp. Cl A)', 'value': 'AGC'},
#  {'label': 'AGCB (Altimeter Growth Corp. 2 Cl A)', 'value': 'AGCB'},
#  {'label': 'AVOT (American Video Teleconferencing Corp.)', 'value': 'AVOT'},
#  {'label': 'AVD (American Vanguard Corp.)', 'value': 'AVD'},
#  {'label': 'AMT (American Tower REIT)', 'value': 'AMT'},
#  {'label': 'AMSC (American Superconductor Corp.)', 'value': 'AMSC'},
#  {'label': 'AWR (American States Water Co.)', 'value': 'AWR'},
#  {'label': 'AMSWA (American Software Inc. Cl A)', 'value': 'AMSWA'},
#  {'label': 'AMNP (American Sierra Gold Corp.)', 'value': 'AMNP'},
#  {'label': 'ASCJF (American Shipping Co. ASA)', 'value': 'ASCJF'},
#  {'label': 'AMS (American Shared Hospital Services)', 'value': 'AMS'},
#  {'label': 'ARSC (American Security Resources Corp.)', 'value': 'ARSC'},
#  {'label': 'ARBV (American Riviera Bank)', 'value': 'ARBV'},
#  {'label': 'ARECW (American Resources Corp. Wt)', 'value': 'ARECW'},
#  {'label': 'AREC (American Resources Corp.)', 'value': 'AREC'},
#  {'label': 'AREB (American Rebel Holdings Inc.)', 'value': 'AREB'},
#  {'label': 'ARL (American Realty Investors Inc.)', 'value': 'ARL'},
#  {'label': 'APEI (American Public Education Inc.)', 'value': 'APEI'},
#  {'label': 'ATBPF (Antibe Therapeutics Inc.)', 'value': 'ATBPF'},
#  {'label': 'ANTH (Anthera Pharmaceuticals Inc.)', 'value': 'ANTH'},
#  {'label': 'ADALU (Anthemis Digital Acquisitions I Corp.)', 'value': 'ADALU'},
#  {'label': 'ANTM (Anthem Inc.)', 'value': 'ANTM'},
#  {'label': 'AR (Antero Resources Corp.)', 'value': 'AR'},
#  {'label': 'AM (Antero Midstream Corp.)', 'value': 'AM'},
#  {'label': 'AMEUF (Anteris Technologies Ltd.)', 'value': 'AMEUF'},
#  {'label': 'ATEX (Anterix Inc.)', 'value': 'ATEX'},
#  {'label': 'AEHL (Antelope Enterprise Holdings Ltd.)', 'value': 'AEHL'},
#  {'label': 'ATRS (Antares Pharma Inc.)', 'value': 'ATRS'},
#  {'label': 'ANPDY (Anta Sports Products Ltd. ADR)', 'value': 'ANPDY'},
#  {'label': 'ANPDF (Anta Sports Products Ltd.)', 'value': 'ANPDF'},
#  {'label': 'ANSS (Ansys Inc.)', 'value': 'ANSS'},
#  {'label': 'ANSNF (Anson Resources Ltd.)', 'value': 'ANSNF'},
#  {'label': 'ANSLY (Ansell Ltd. ADR)', 'value': 'ANSLY'},
#  {'label': 'AITUY (Anritsu Corp. ADR)', 'value': 'AITUY'},
#  {'label': 'ARNC (Arconic Corp.)', 'value': 'ARNC'},
#  {'label': 'ARCE (Arco Platform Ltd. Cl A)', 'value': 'ARCE'},
#  {'label': 'ACTDW (ArcLight Clean Transition Corp. II Wt)', 'value': 'ACTDW'},
#  {'label': 'ACTD (ArcLight Clean Transition Corp. II Cl A)', 'value': 'ACTD'},
#  {'label': 'ACTDU (ArcLight Clean Transition Corp. II)', 'value': 'ACTDU'},
#  {'label': 'FUV (Arcimoto Inc.)', 'value': 'FUV'},
#  {'label': 'AROC (Archrock Inc.)', 'value': 'AROC'},
#  {'label': 'ATSPW (Archimedes Tech SPAC Partners Co. Wt)', 'value': 'ATSPW'},
#  {'label': 'ATSPT (Archimedes Tech SPAC Partners Co. Sub. Un)',
#   'value': 'ATSPT'},
#  {'label': 'ATSPU (Archimedes Tech SPAC Partners Co.)', 'value': 'ATSPU'},
#  {'label': 'ARRXF (Archer Materials Ltd.)', 'value': 'ARRXF'},
#  {'label': 'ARHVF (Archer Ltd.)', 'value': 'ARHVF'},
#  {'label': 'ADM (Archer Daniels Midland Co.)', 'value': 'ADM'},
#  {'label': 'ACHR.WT (Archer Aviation Inc. Wt)', 'value': 'ACHR.WT'},
#  {'label': 'ACHR (Archer Aviation Inc.)', 'value': 'ACHR'},
#  {'label': 'LFG.WT (Archaea Energy Inc. Wt)', 'value': 'LFG.WT'},
#  {'label': 'ASHTF (Ashtead Group PLC)', 'value': 'ASHTF'},
#  {'label': 'ASH (Ashland Global Holdings Inc.)', 'value': 'ASH'},
#  {'label': 'AINC (Ashford Inc.)', 'value': 'AINC'},
#  {'label': 'AHT.PRD (Ashford Hospitality Trust Inc. 8.45% Cum. Pfd. Series D)',
#   'value': 'AHT.PRD'},
#  {'label': 'AHT.PRF (Ashford Hospitality Trust Inc. 7.375% Pfd. Series F)',
#   'value': 'AHT.PRF'},
#  {'label': 'AHT.PRI (Ashford Hospitality Trust 7.5% Pfd. Series I)',
#   'value': 'AHT.PRI'},
#  {'label': 'AHT.PRH (Ashford Hospitality Trust 7.5% Cum. Pfd. Series H)',
#   'value': 'AHT.PRH'},
#  {'label': 'AHT.PRG (Ashford Hospitality Trust 7.375% Cum. Pfd. Series G)',
#   'value': 'AHT.PRG'},
#  {'label': 'AHT (Ashford Hospitality Trust)', 'value': 'AHT'},
#  {'label': 'ASGN (ASGN Inc.)', 'value': 'ASGN'},
#  {'label': 'ASKTF (Asetek A/S)', 'value': 'ASKTF'},
#  {'label': 'TRXDW (Asensus Surgical Inc. Wt)', 'value': 'TRXDW'},
#  {'label': 'ASXC (Asensus Surgical Inc.)', 'value': 'ASXC'},
#  {'label': 'ASX (ASE Technology Holding Co. Ltd. ADR)', 'value': 'ASX'},
#  {'label': 'AOTVF (Ascot Resources Ltd.)', 'value': 'AOTVF'},
#  {'label': 'AIAPF (Ascential PLC)', 'value': 'AIAPF'},
#  {'label': 'ACII.UT (Atlas Crest Investment Corp. II)', 'value': 'ACII.UT'},
#  {'label': 'ATCO.PRI (Atlas Corp. Perp. Pfd. Series I)', 'value': 'ATCO.PRI'},
#  {'label': 'ATCO.PRD (Atlas Corp. 7.95% Cum. Redeem. Perp. Pfd. Series D)',
#   'value': 'ATCO.PRD'},
#  {'label': 'ATCO.PRH (Atlas Corp. 7.875% Cum. Redeem. Perp. Pfd. Series H)',
#   'value': 'ATCO.PRH'},
#  {'label': 'ATCOL (Atlas Corp. 7.125% Notes due 2027)', 'value': 'ATCOL'},
#  {'label': 'ATCO (Atlas Corp.)', 'value': 'ATCO'},
#  {'label': 'ATTLF (Atlas Copco AB Series B)', 'value': 'ATTLF'},
#  {'label': 'ATLCY (Atlas Copco AB Series B ADR)', 'value': 'ATLCY'},
#  {'label': 'ATLKF (Atlas Copco AB Series A)', 'value': 'ATLKF'},
#  {'label': 'ATLKY (Atlas Copco AB ADR)', 'value': 'ATLKY'},
#  {'label': 'ACMDY (Atlas Consolidated Mining & Development Corp. ADR)',
#   'value': 'ACMDY'},
#  {'label': 'MAQAF (Atlas Arteria Ltd.)', 'value': 'MAQAF'},
#  {'label': 'AAWW (Atlas Air Worldwide Holdings)', 'value': 'AAWW'},
#  {'label': 'ATIG (Atlantis Internet Group Corp.)', 'value': 'ATIG'},
#  {'label': 'ATLCP (Atlanticus Holdings Corp. 7.625% Cum. Pfd. Series B)',
#   'value': 'ATLCP'},
#  {'label': 'ATLC (Atlanticus Holdings Corp.)', 'value': 'ATLC'},
#  {'label': 'AVDX (AvidXchange Holdings Inc.)', 'value': 'AVDX'},
#  {'label': 'RNA (Avidity Biosciences Inc.)', 'value': 'RNA'},
#  {'label': 'AVGDF (Avidian Gold Corp.)', 'value': 'AVGDF'},
#  {'label': 'AVBH (Avidbank Holdings Inc.)', 'value': 'AVBH'},
#  {'label': 'AVID (Avid Technology Inc.)', 'value': 'AVID'},
#  {'label': 'CDMO (Avid Bioservices Inc.)', 'value': 'CDMO'},
#  {'label': 'AVCNF (Avicanna Inc.)', 'value': 'AVCNF'},
#  {'label': 'AVNW (Aviat Networks Inc.)', 'value': 'AVNW'},
#  {'label': 'AVEW (AVEW Holdings Inc.)', 'value': 'AVEW'},
#  {'label': 'AVVYY (Aveva Group PLC ADR)', 'value': 'AVVYY'},
#  {'label': 'AVEVF (Aveva Group PLC)', 'value': 'AVEVF'},
#  {'label': 'AVY (Avery Dennison Corp.)', 'value': 'AVY'},
#  {'label': 'AVRI (Averox Inc.)', 'value': 'AVRI'},
#  {'label': 'AVPTW (AvePoint Inc. Wt)', 'value': 'AVPTW'},
#  {'label': 'AVPT (AvePoint Inc. Cl A)', 'value': 'AVPT'},
#  {'label': 'AVEO (AVEO Pharmaceuticals Inc.)', 'value': 'AVEO'},
#  {'label': 'BBDO (Banco Bradesco S/A Ord ADR)', 'value': 'BBDO'},
#  {'label': 'BBVA (Banco Bilbao Vizcaya Argentaria S.A. ADR)', 'value': 'BBVA'},
#  {'label': 'BBVXF (Banco Bilbao Vizcaya Argentaria S.A.)', 'value': 'BBVXF'},
#  {'label': 'BBAR (Banco BBVA Argentina S.A. ADR)', 'value': 'BBAR'},
#  {'label': 'BANF (BancFirst Corp.)', 'value': 'BANF'},
#  {'label': 'BMDPF (Banca Monte dei Paschi di Siena S.p.A.)', 'value': 'BMDPF'},
#  {'label': 'BNCDY (Banca Mediolanum S.p.A. ADR)', 'value': 'BNCDY'},
#  {'label': 'BNMDF (Banca Mediolanum S.p.A.)', 'value': 'BNMDF'},
#  {'label': 'BANC.PRE (Banc of California Inc. Dep.Pfd. (Rep. 1/40th Non-Cum. 7% Perp. Pfd. Series E))',
#   'value': 'BANC.PRE'},
#  {'label': 'BANC (Banc of California Inc.)', 'value': 'BANC'},
#  {'label': 'NPEZF (Bam Bam Resources Corp.)', 'value': 'NPEZF'},
#  {'label': 'BISA (Baltic International USA Inc.)', 'value': 'BISA'},
#  {'label': 'BLHEY (Baloise-Holding AG ADR)', 'value': 'BLHEY'},
#  {'label': 'BLHEF (Baloise-Holding AG)', 'value': 'BLHEF'},
#  {'label': "BALY (Bally's Corp.)", 'value': 'BALY'},
#  {'label': 'BLYQ (Bally Corp.)', 'value': 'BLYQ'},
#  {'label': 'BYSD (Bayside Corp.)', 'value': 'BYSD'},
#  {'label': 'BAYP (Bayport International Holdings Inc.)', 'value': 'BAYP'},
#  {'label': 'BYLTF (Baylin Technologies Inc.)', 'value': 'BYLTF'},
#  {'label': 'BHSIF (Bayhorse Silver Inc.)', 'value': 'BHSIF'},
#  {'label': 'FHBI (BayFirst Financial Corp.)', 'value': 'FHBI'},
#  {'label': 'BYMOF (Bayerische Motoren Werke AG Pfd.)', 'value': 'BYMOF'},
#  {'label': 'BMWYY (Bayerische Motoren Werke AG ADR)', 'value': 'BMWYY'},
#  {'label': 'BAMXF (Bayerische Motoren Werke AG)', 'value': 'BAMXF'},
#  {'label': 'BAYRY (Bayer AG ADR)', 'value': 'BAYRY'},
#  {'label': 'BAYZF (Bayer AG)', 'value': 'BAYZF'},
#  {'label': 'BYCRF (BayCurrent Consulting Inc.)', 'value': 'BYCRF'},
#  {'label': 'BCML (BayCom Corp.)', 'value': 'BCML'},
#  {'label': 'CBOBA (Bay Community Bancorp)', 'value': 'CBOBA'},
#  {'label': 'BAX (Baxter International Inc.)', 'value': 'BAX'},
#  {'label': 'BVNRY (Bavarian Nordic A/S ADR)', 'value': 'BVNRY'},
#  {'label': 'BH (Biglari Holdings Inc. Cl B)', 'value': 'BH'},
#  {'label': 'BCDS (Blaqclouds Inc.)', 'value': 'BCDS'},
#  {'label': 'BLDEW (Blade Air Mobility Inc. Wt)', 'value': 'BLDEW'},
#  {'label': 'BLDE (Blade Air Mobility Inc.)', 'value': 'BLDE'},
#  {'label': 'BWCGF (Blackwolf Copper & Gold Ltd.)', 'value': 'BWCGF'},
#  {'label': 'BXMT (Blackstone Mortgage Trust Inc. Cl A)', 'value': 'BXMT'},
#  {'label': 'BLSTF (Blackstone Minerals Ltd.)', 'value': 'BLSTF'},
#  {'label': 'BX (Blackstone Inc.)', 'value': 'BX'},
#  {'label': 'BEGI (BlackStar Enterprise Group Inc.)', 'value': 'BEGI'},
#  {'label': 'BKSY.WT (BlackSky Technology Inc. Wt)', 'value': 'BKSY.WT'},
#  {'label': 'BKSY (BlackSky Technology Inc.)', 'value': 'BKSY'},
#  {'label': 'TCPC (BlackRock TCP Capital Corp.)', 'value': 'TCPC'},
#  {'label': 'BKRRF (Blackrock Silver Corp.)', 'value': 'BKRRF'},
#  {'label': 'BLK (BlackRock Inc.)', 'value': 'BLK'},
#  {'label': 'BKCC (BlackRock Capital Investment Corp.)', 'value': 'BKCC'},
#  {'label': 'BKMP (Blackout Media Corp.)', 'value': 'BKMP'},
#  {'label': 'BOMN (Boston Omaha Corp.)', 'value': 'BOMN'},
#  {'label': 'SAM (Boston Beer Co. Cl A)', 'value': 'SAM'},
#  {'label': 'BQSSF (Boss Energy Ltd.)', 'value': 'BQSSF'},
#  {'label': 'BSDGF (Bosideng International Holdings Ltd.)', 'value': 'BSDGF'},
#  {'label': 'BORUF (Borussia Dortmund GmbH & Co. KGaA)', 'value': 'BORUF'},
#  {'label': 'BWMY (Borrowmoney.com Inc.)', 'value': 'BWMY'},
#  {'label': 'BRRDF (Borregaard ASA)', 'value': 'BRRDF'},
#  {'label': 'BORR (Borr Drilling Ltd.)', 'value': 'BORR'},
#  {'label': 'BRQSW (Borqs Technologies Inc. Wt)', 'value': 'BRQSW'},
#  {'label': 'BRQS (Borqs Technologies Inc.)', 'value': 'BRQS'},
#  {'label': 'BRNE (Borneo Resource Investments Ltd.)', 'value': 'BRNE'},
#  {'label': 'BRRN (Born Inc.)', 'value': 'BRRN'},
#  {'label': 'BWA (BorgWarner Inc.)', 'value': 'BWA'},
#  {'label': 'BOREF (Borealis Exploration Ltd.)', 'value': 'BOREF'},
#  {'label': 'BRLXF (Boralex Inc. Cl A)', 'value': 'BRLXF'},
#  {'label': 'BKFAF (Brookfield Asset Management Inc. Cum. Redeem. Pfd. A Series 2)',
#   'value': 'BKFAF'},
#  {'label': 'CZR (Caesars Entertainment Inc.)', 'value': 'CZR'},
#  {'label': 'CAE (CAE Inc.)', 'value': 'CAE'},
#  {'label': 'CDRE (Cadre Holdings Inc.)', 'value': 'CDRE'},
#  {'label': 'CDZIP (Cadiz Inc. Dep. Pfd. (Rep. 1/1000th Share Pfd. A))',
#   'value': 'CDZIP'},
#  {'label': 'CDZI (Cadiz Inc.)', 'value': 'CDZI'},
#  {'label': 'CDNS (Cadence Design Systems Inc.)', 'value': 'CDNS'},
#  {'label': 'CADE.PRA (Cadence Bank 5.5% Non-Cum. Pfd. Series A)',
#   'value': 'CADE.PRA'},
#  {'label': 'CADE (Cadence Bank)', 'value': 'CADE'},
#  {'label': 'WHD (Cactus Inc. Cl A)', 'value': 'WHD'},
#  {'label': 'CCTSU (Cactus Acquisition Corp. 1 Ltd.)', 'value': 'CCTSU'},
#  {'label': 'CACI (CACI International Inc. Cl A)', 'value': 'CACI'},
#  {'label': 'CACH (Cache Inc.)', 'value': 'CACH'},
#  {'label': 'CEXPF (Cache Exploration Inc.)', 'value': 'CEXPF'},
#  {'label': 'CBGZF (Cabral Gold Inc.)', 'value': 'CBGZF'},
#  {'label': 'COF.PRH (Capital One Financial Corp. Dep. Pfd. (Rep. 1/40th Share Pfd. Series H))',
#   'value': 'COF.PRH'},
#  {'label': 'COF.PRN (Capital One Financial Corp. Dep. Pfd. (Rep. 1/40th Perp. Pfd. Series N))',
#   'value': 'COF.PRN'},
#  {'label': 'COF.PRL (Capital One Financial Corp. Dep. Pfd. (Rep. 1/40th Perp. Pfd. Series L))',
#   'value': 'COF.PRL'},
#  {'label': 'COF.PRK (Capital One Financial Corp. Dep. Pfd. (Rep. 1/40th Perp. Pfd. Series K))',
#   'value': 'COF.PRK'},
#  {'label': 'COF.PRI (Capital One Financial Corp. Dep. Pfd. (Rep. 1/40th Perp. Pfd. Series I))',
#   'value': 'COF.PRI'},
#  {'label': 'COF.PRG (Capital One Financial Corp. Dep. Pfd. (Rep. 1/40th Fixed Rate Non-Cum. Perp. Pfd. Series G))',
#   'value': 'COF.PRG'},
#  {'label': 'COF.PRJ (Capital One Financial Corp. Dep Pfd. (Rep. 1/40th Perp. Pfd. Series J))',
#   'value': 'COF.PRJ'},
#  {'label': 'COF (Capital One Financial Corp.)', 'value': 'COF'},
#  {'label': 'CFGX (Capital Financial Global Inc.)', 'value': 'CFGX'},
#  {'label': 'CCBG (Capital City Bank Group Inc.)', 'value': 'CCBG'},
#  {'label': 'CBNK (Capital Bancorp Inc.)', 'value': 'CBNK'},
#  {'label': 'CTAGY (Capita PLC ADR)', 'value': 'CTAGY'},
#  {'label': 'FPSUF (Capha Pharmaceuticals Inc.)', 'value': 'FPSUF'},
#  {'label': 'CGEMY (Capgemini SE ADR)', 'value': 'CGEMY'},
#  {'label': 'CAPMF (Capgemini SE)', 'value': 'CAPMF'},
#  {'label': 'CBL (CBL & Associates Properties Inc.)', 'value': 'CBL'},
#  {'label': 'CF (CF Industries Holdings Inc.)', 'value': 'CF'},
#  {'label': 'CFBK (CF Bankshares Inc.)', 'value': 'CFBK'},
#  {'label': 'CFFEW (CF Acquisition Corp. VIII Wt)', 'value': 'CFFEW'},
#  {'label': 'CFFE (CF Acquisition Corp. VIII Cl A)', 'value': 'CFFE'},
#  {'label': 'CFFEU (CF Acquisition Corp. VIII)', 'value': 'CFFEU'},
#  {'label': 'CFVIW (CF Acquisition Corp. VI Wt)', 'value': 'CFVIW'},
#  {'label': 'CFVI (CF Acquisition Corp. VI Cl A)', 'value': 'CFVI'},
#  {'label': 'CFVIU (CF Acquisition Corp. VI)', 'value': 'CFVIU'},
#  {'label': 'CFFVW (CF Acquisition Corp. V Wt)', 'value': 'CFFVW'},
#  {'label': 'CFV (CF Acquisition Corp. V Cl A)', 'value': 'CFV'},
#  {'label': 'CFFVU (CF Acquisition Corp. V)', 'value': 'CFFVU'},
#  {'label': 'CFIVW (CF Acquisition Corp. IV Wt)', 'value': 'CFIVW'},
#  {'label': 'CFIV (CF Acquisition Corp. IV Cl A)', 'value': 'CFIV'},
#  {'label': 'CFIVU (CF Acquisition Corp. IV)', 'value': 'CFIVU'},
#  {'label': 'CYLYF (Ceylon Graphite Corp.)', 'value': 'CYLYF'},
#  {'label': 'CIADY (China Mengniu Dairy Co. Ltd. ADR)', 'value': 'CIADY'},
#  {'label': 'CHME (China Medicine Corp.)', 'value': 'CHME'},
#  {'label': 'CMFO (China Marine Food Group Ltd.)', 'value': 'CMFO'},
#  {'label': 'CLPXY (China Longyuan Power Group Corp. Ltd. ADR)',
#   'value': 'CLPXY'},
#  {'label': 'CLPXF (China Longyuan Power Group Corp. Ltd.)', 'value': 'CLPXF'},
#  {'label': 'LFC (China Life Insurance Co. Ltd. ADR)', 'value': 'LFC'},
#  {'label': 'CILJF (China Life Insurance Co. Ltd.)', 'value': 'CILJF'},
#  {'label': 'CLEU (China Liberal Education Holdings Ltd.)', 'value': 'CLEU'},
#  {'label': 'CJJD (China Jo-Jo Drugstores Inc.)', 'value': 'CJJD'},
#  {'label': 'CNICF (China International Capital Corp. Ltd.)', 'value': 'CNICF'},
#  {'label': 'IICN (China Intelligence Information Systems Inc.)',
#   'value': 'IICN'},
#  {'label': 'CHNC (China Infrastructure Construction Corp.)', 'value': 'CHNC'},
#  {'label': 'CIH (China Index Holdings Ltd. ADR)', 'value': 'CIH'},
#  {'label': 'CHHQY (China Hongqiao Group Ltd. ADR)', 'value': 'CHHQY'},
#  {'label': 'CHHL (China Holdings Inc.)', 'value': 'CHHL'},
#  {'label': 'CBAF (Citba Financial Corp.)', 'value': 'CBAF'},
#  {'label': 'CMSA (CMS Energy Corp. 5.625% Jr. Sub. Deb. 2078)',
#   'value': 'CMSA'},
#  {'label': 'CMS (CMS Energy Corp.)', 'value': 'CMS'},
#  {'label': 'CMKI (CMK Gaming International Inc.)', 'value': 'CMKI'},
#  {'label': 'CMGO (CMG Holdings Group Inc.)', 'value': 'CMGO'},
#  {'label': 'CME (CME Group Inc. Cl A)', 'value': 'CME'},
#  {'label': 'CMCXF (CMC Metals Ltd.)', 'value': 'CMCXF'},
#  {'label': 'CCMP (CMC Materials Inc.)', 'value': 'CCMP'},
#  {'label': 'CMLTW (CM Life Sciences III Inc. Wt)', 'value': 'CMLTW'},
#  {'label': 'CMLT (CM Life Sciences III Inc. Cl A)', 'value': 'CMLT'},
#  {'label': 'CMLTU (CM Life Sciences III Inc.)', 'value': 'CMLTU'},
#  {'label': 'CMGR (Clubhouse Media Group Inc.)', 'value': 'CMGR'},
#  {'label': 'CLHI (CLST Holdings Inc.)', 'value': 'CLHI'},
#  {'label': 'CLSH (CLS Holdings USA Inc.)', 'value': 'CLSH'},
#  {'label': 'CLPS (CLPS Inc.)', 'value': 'CLPS'},
#  {'label': 'CLPHY (CLP Holdings Ltd. ADR)', 'value': 'CLPHY'},
#  {'label': 'CODYY (Compagnie de Saint-Gobain S.A. ADR)', 'value': 'CODYY'},
#  {'label': 'CODGF (Compagnie de Saint-Gobain S.A.)', 'value': 'CODGF'},
#  {'label': 'CVLT (CommVault Systems Inc.)', 'value': 'CVLT'},
#  {'label': 'CWBC (Community West Bancshares)', 'value': 'CWBC'},
#  {'label': 'CTBI (Community Trust Bancorp Inc.)', 'value': 'CTBI'},
#  {'label': 'CCSB (Community Savings Bancorp Inc.)', 'value': 'CCSB'},
#  {'label': 'CRDV (Community Redevelopment Inc.)', 'value': 'CRDV'},
#  {'label': 'CIBN (Community Investors Bancorp Inc.)', 'value': 'CIBN'},
#  {'label': 'CMHF (Community Heritage Financial Inc.)', 'value': 'CMHF'},
#  {'label': 'CHCT (Community Healthcare Trust Inc.)', 'value': 'CHCT'},
#  {'label': 'CYH (Community Health Systems Inc.)', 'value': 'CYH'},
#  {'label': 'CFOK (Community First Bancorp)', 'value': 'CFOK'},
#  {'label': 'TCFC (Community Financial Corp.)', 'value': 'TCFC'},
#  {'label': 'ALBY (Community Capital Bancshares Inc.)', 'value': 'ALBY'},
#  {'label': 'ESXB (Community Bankers Trust Corp.)', 'value': 'ESXB'},
#  {'label': 'CPPMF (Copper Mountain Mining Corp.)', 'value': 'CPPMF'},
#  {'label': 'CRCT (Cricut Inc. Cl A)', 'value': 'CRCT'},
#  {'label': 'CRH (CRH PLC ADR)', 'value': 'CRH'},
#  {'label': 'CRHCF (CRH PLC)', 'value': 'CRHCF'},
#  {'label': 'CXDO (Crexendo Inc.)', 'value': 'CXDO'},
#  {'label': 'CWEGF (Crew Energy Inc.)', 'value': 'CWEGF'},
#  {'label': 'CRESY (Cresud S.A.C.I.F. y A. ADR)', 'value': 'CRESY'},
#  {'label': 'CRESW (Cresud S.A.C.I.F. y A. Wt)', 'value': 'CRESW'},
#  {'label': 'CEQP.PR (Crestwood Equity Partners LP Un)', 'value': 'CEQP.PR'},
#  {'label': 'CEQP (Crestwood Equity Partners LP)', 'value': 'CEQP'},
#  {'label': 'CRSTF (Crest Resources Inc.)', 'value': 'CRSTF'},
#  {'label': 'CRLWF (Cresco Labs Inc. Wt)', 'value': 'CRLWF'},
#  {'label': 'CRLBF (Cresco Labs Inc.)', 'value': 'CRLBF'},
#  {'label': 'CRRTF (Crescita Therapeutics Inc.)', 'value': 'CRRTF'},
#  {'label': 'CPG (Crescent Point Energy Corp.)', 'value': 'CPG'},
#  {'label': 'CCAP (Crescent Capital BDC Inc.)', 'value': 'CCAP'},
#  {'label': 'CYT (Cyteir Therapeutics Inc.)', 'value': 'CYT'},
#  {'label': 'CONE (CyrusOne Inc.)', 'value': 'CONE'},
#  {'label': 'CYRN (CYREN Ltd.)', 'value': 'CYRN'},
#  {'label': 'CYRBY (Cyrela Brazil Realty S.A. ADR)', 'value': 'CYRBY'},
#  {'label': 'CELP (Cypress Environmental Partners L.P.)', 'value': 'CELP'},
#  {'label': 'CYDVF (Cypress Development Corp.)', 'value': 'CYDVF'},
#  {'label': 'KHRIF (Cypherpunk Holdings Inc.)', 'value': 'KHRIF'},
#  {'label': 'CYN (Cyngn Inc.)', 'value': 'CYN'},
#  {'label': 'CTEK (CynergisTek Inc.)', 'value': 'CTEK'},
#  {'label': 'CYYNF (Cynata Therapeutics Ltd.)', 'value': 'CYYNF'},
#  {'label': 'CBAY (CymaBay Therapeutics Inc.)', 'value': 'CBAY'},
#  {'label': 'CYIO (CYIOS Corp.)', 'value': 'CYIO'},
#  {'label': 'CYDX (CYduct Diagnostics Inc.)', 'value': 'CYDX'},
#  {'label': 'CYTHW (Cyclo Therapeutics Inc. Wt)', 'value': 'CYTHW'},
#  {'label': 'CYTH (Cyclo Therapeutics Inc.)', 'value': 'CYTH'},
#  {'label': 'DTII (Defense Technologies International Corp.)', 'value': 'DTII'},
#  {'label': 'DWACW (Digital World Acquisition Corp. Wt)', 'value': 'DWACW'},
#  {'label': 'DWAC (Digital World Acquisition Corp. Cl A)', 'value': 'DWAC'},
#  {'label': 'DWACU (Digital World Acquisition Corp.)', 'value': 'DWACU'},
#  {'label': 'APPS (Digital Turbine Inc.)', 'value': 'APPS'},
#  {'label': 'DUTV (Digital Utilities Ventures Inc.)', 'value': 'DUTV'},
#  {'label': 'DTOCW (Digital Transformation Opportunities Corp. Wt)',
#   'value': 'DTOCW'},
#  {'label': 'DTOC (Digital Transformation Opportunities Corp. Cl A)',
#   'value': 'DTOC'},
#  {'label': 'DTOCU (Digital Transformation Opportunities Corp.)',
#   'value': 'DTOCU'},
#  {'label': 'DLR.PRK (Digital Realty Trust Inc. 5.85% Conv. Redeem. Pfd. Series K)',
#   'value': 'DLR.PRK'},
#  {'label': 'DLR.PRJ (Digital Realty Trust Inc. 5.25% Cum. Conv. Pfd. Series J)',
#   'value': 'DLR.PRJ'},
#  {'label': 'DLR (Digital Realty Trust Inc.)', 'value': 'DLR'},
#  {'label': 'DLR.PRL (Digital Realty Trust Inc. 5.2% Cum. Redeem. Pfd. Series L)',
#   'value': 'DLR.PRL'},
#  {'label': 'DMS.WT (Digital Media Solutions Inc. Wt)', 'value': 'DMS.WT'},
#  {'label': 'DMS (Digital Media Solutions Inc.)', 'value': 'DMS'},
#  {'label': 'DLOC (Digital Locations Inc.)', 'value': 'DLOC'},
#  {'label': 'DRUNF (DREAM Unlimited Corp.)', 'value': 'DRUNF'},
#  {'label': 'DRETF (Dream Office Real Estate Investment Trust)',
#   'value': 'DRETF'},
#  {'label': 'DREUF (Dream Industrial Real Estate Investment Trust)',
#   'value': 'DREUF'},
#  {'label': 'DREM (Dream Homes & Development Corp.)', 'value': 'DREM'},
#  {'label': 'DFH (Dream Finders Homes Inc. Cl A)', 'value': 'DFH'},
#  {'label': 'DRD (DRDGOLD Ltd. ADR)', 'value': 'DRD'},
#  {'label': 'DRDGF (DRDGOLD Ltd.)', 'value': 'DRDGF'},
#  {'label': 'DRXGF (Drax Group PLC)', 'value': 'DRXGF'},
#  {'label': 'GRWXF (Draper Esprit PLC)', 'value': 'GRWXF'},
#  {'label': 'DGNU (Dragoneer Growth Opportunities Corp. III Cl A)',
#   'value': 'DGNU'},
#  {'label': 'DGNS (Dragoneer Growth Opportunities Corp. II Cl A)',
#   'value': 'DGNS'},
#  {'label': 'LYL (Dragon Victory International Ltd.)', 'value': 'LYL'},
#  {'label': 'DRGV (Dragon Capital Group Corp.)', 'value': 'DRGV'},
#  {'label': 'DPRO (Draganfly Inc.)', 'value': 'DPRO'},
#  {'label': 'DKNG (DraftKings Inc. Cl A)', 'value': 'DKNG'},
#  {'label': 'EAPH (Easton Pharmaceuticals Inc.)', 'value': 'EAPH'},
#  {'label': 'ELIXF (Elixxer Ltd.)', 'value': 'ELIXF'},
#  {'label': 'ELLXF (Elixinol Wellness Ltd.)', 'value': 'ELLXF'},
#  {'label': 'ELTP (Elite Pharmaceuticals Inc.)', 'value': 'ELTP'},
#  {'label': 'EEIQ (Elite Education Group International Ltd.)', 'value': 'EEIQ'},
#  {'label': 'ELMUF (Elisa Oyj)', 'value': 'ELMUF'},
#  {'label': 'ELIO (Elio Motors Inc.)', 'value': 'ELIO'},
#  {'label': 'EEGI (Eline Entertainment Group Inc.)', 'value': 'EEGI'},
#  {'label': 'ELYM (Eliem Therapeutics Inc.)', 'value': 'ELYM'},
#  {'label': 'LLY (Eli Lilly & Co.)', 'value': 'LLY'},
#  {'label': 'ELEV (Elevation Oncology Inc.)', 'value': 'ELEV'},
#  {'label': 'NHVCF (Elevation Gold Mining Corp.)', 'value': 'NHVCF'},
#  {'label': 'ELVUF (Elevate Uranium Ltd.)', 'value': 'ELVUF'},
#  {'label': 'ELVT (Elevate Credit Inc.)', 'value': 'ELVT'},
#  {'label': 'ELTLF (Elementos Ltd.)', 'value': 'ELTLF'},
#  {'label': 'EMNSF (Elementis PLC)', 'value': 'EMNSF'},
#  {'label': 'GAME (Engine Gaming & Media Inc.)', 'value': 'GAME'},
#  {'label': 'ENGIY (Engie S.A. ADR)', 'value': 'ENGIY'},
#  {'label': 'ENGQF (Engie S.A.)', 'value': 'ENGQF'},
#  {'label': 'EGIEY (ENGIE Brasil Energia S/A ADR)', 'value': 'EGIEY'},
#  {'label': 'EGHSF (Enghouse Systems Ltd.)', 'value': 'EGHSF'},
#  {'label': 'ESMT (EngageSmart Inc.)', 'value': 'ESMT'},
#  {'label': 'ELBSF (Engagement Labs Inc.)', 'value': 'ELBSF'},
#  {'label': 'ENGA (Engage Mobility Inc.)', 'value': 'ENGA'},
#  {'label': 'ENFN (Enfusion Inc.)', 'value': 'ENFN'},
#  {'label': 'NETI (Eneti Inc.)', 'value': 'NETI'},
#  {'label': 'ENRT (Enertopia Corp.)', 'value': 'ENRT'},
#  {'label': 'ETCK (EnerTeck Corp.)', 'value': 'ETCK'},
#  {'label': 'ENS (EnerSys)', 'value': 'ENS'},
#  {'label': 'ERF (Enerplus Corp.)', 'value': 'ERF'},
#  {'label': 'EPAC (Enerpac Tool Group Corp. Cl A)', 'value': 'EPAC'},
#  {'label': 'ERO (Ero Copper Corp.)', 'value': 'ERO'},
#  {'label': 'EXN (Excellon Resources Inc.)', 'value': 'EXN'},
#  {'label': 'EXCL (Excellerant Inc.)', 'value': 'EXCL'},
#  {'label': 'XFINU (ExcelFin Acquisition Corp.)', 'value': 'XFINU'},
#  {'label': 'EXDW (Exceed World Inc.)', 'value': 'EXDW'},
#  {'label': 'XGN (Exagen Inc.)', 'value': 'XGN'},
#  {'label': 'EXAS (Exact Sciences Corp.)', 'value': 'EXAS'},
#  {'label': 'EWRC (eWorld Cos. Inc.)', 'value': 'EWRC'},
#  {'label': 'EWLL (eWellness Healthcare Corp.)', 'value': 'EWLL'},
#  {'label': 'EVSBY (EVS Broadcast Equipment S.A. ADR)', 'value': 'EVSBY'},
#  {'label': 'EVRZF (Evraz PLC)', 'value': 'EVRZF'},
#  {'label': 'EVO (Evotec SE ADR)', 'value': 'EVO'},
#  {'label': 'EVOTF (Evotec SE)', 'value': 'EVOTF'},
#  {'label': 'AQUA (Evoqua Water Technologies Corp.)', 'value': 'AQUA'},
#  {'label': 'EVKIF (Evonik Industries AG)', 'value': 'EVKIF'},
#  {'label': 'EVOL (Evolving Systems Inc.)', 'value': 'EVOL'},
#  {'label': 'CAOHF (FDG Electric Vehicles Ltd.)', 'value': 'CAOHF'},
#  {'label': 'FDCT (FDCTech Inc.)', 'value': 'FDCT'},
#  {'label': 'FDRVF (FD Technologies PLC)', 'value': 'FDRVF'},
#  {'label': 'FCIC (FCCC Inc.)', 'value': 'FCIC'},
#  {'label': 'FBRKF (FBR Ltd.)', 'value': 'FBRKF'},
#  {'label': 'FBEC (FBEC Worldwide Inc.)', 'value': 'FBEC'},
#  {'label': 'FBCD (FBC Holding Inc.)', 'value': 'FBCD'},
#  {'label': 'FBK (FB Financial Corp.)', 'value': 'FBK'},
#  {'label': 'FAVO (FAVO Capital Inc.)', 'value': 'FAVO'},
#  {'label': 'FURCF (Faurecia S.E.)', 'value': 'FURCF'},
#  {'label': 'FNICF (Fathom Nickel Inc.)', 'value': 'FNICF'},
#  {'label': 'FTHM (Fathom Holdings Inc.)', 'value': 'FTHM'},
#  {'label': 'FATE (Fate Therapeutics Inc.)', 'value': 'FATE'},
#  {'label': 'FATPU (Fat Projects Acquisition Corp.)', 'value': 'FATPU'},
#  {'label': 'FATBW (FAT Brands Inc. Wt)', 'value': 'FATBW'},
#  {'label': 'FCRX (First Eagle Alternative Capital BDC Inc. 5% Notes due 2026)',
#   'value': 'FCRX'},
#  {'label': 'PDYPF (Flutter Entertainment PLC)', 'value': 'PDYPF'},
#  {'label': 'FFIC (Flushing Financial Corp.)', 'value': 'FFIC'},
#  {'label': 'FLURF (Flurotech Ltd.)', 'value': 'FLURF'},
#  {'label': 'FLR (Fluor Corp.)', 'value': 'FLR'},
#  {'label': 'FLUIF (Fluidra S.A.)', 'value': 'FLUIF'},
#  {'label': 'FLDM (Fluidigm Corp.)', 'value': 'FLDM'},
#  {'label': 'FLGZY (Flughafen Zuerich AG ADR)', 'value': 'FLGZY'},
#  {'label': 'UZAPF (Flughafen Zuerich AG)', 'value': 'UZAPF'},
#  {'label': 'VIAAY (Flughafen Wien AG ADR)', 'value': 'VIAAY'},
#  {'label': 'FLNT (Fluent Inc.)', 'value': 'FLNT'},
#  {'label': 'FLNC (Fluence Energy Inc.)', 'value': 'FLNC'},
#  {'label': 'EMFGF (Fluence Corp Ltd.)', 'value': 'EMFGF'},
#  {'label': 'FLIDF (FLSmidth & Co. A/S)', 'value': 'FLIDF'},
#  {'label': 'FLIDY (FLSmidth & Co. A/S ADR)', 'value': 'FLIDY'},
#  {'label': 'FLS (Flowserve Corp.)', 'value': 'FLS'},
#  {'label': 'FMCCO (Freddie Mac 5.8% Non-Cum. Pfd.)', 'value': 'FMCCO'},
#  {'label': 'FMCCK (Freddie Mac 5.79% Pfd.)', 'value': 'FMCCK'},
#  {'label': 'FMCKP (Freddie Mac 5.7% Non-Cum. Pfd.)', 'value': 'FMCKP'},
#  {'label': 'FMCKN (Freddie Mac 5.66% Non-Cum. Perp. Pfd.)', 'value': 'FMCKN'},
#  {'label': 'FMCKM (Freddie Mac 5.57% Non-Cum. Perp. Pfd.)', 'value': 'FMCKM'},
#  {'label': 'FMCCH (Freddie Mac 5.10% Non Cum. Pfd.)', 'value': 'FMCCH'},
#  {'label': 'FMCKK (Freddie Mac 5% Non Cum. Pfd.)', 'value': 'FMCKK'},
#  {'label': 'FMCC (Freddie Mac)', 'value': 'FMCC'},
#  {'label': 'FLACW (Frazier Lifesciences Acquisition Corp. Wt)',
#   'value': 'FLACW'},
#  {'label': 'FLAC (Frazier Lifesciences Acquisition Corp. Cl A)',
#   'value': 'FLAC'},
#  {'label': 'FLACU (Frazier Lifesciences Acquisition Corp.)', 'value': 'FLACU'},
#  {'label': 'FRLOF (Frasers Logistics & Commercial Trust)', 'value': 'FRLOF'},
#  {'label': 'FPRUY (Fraport AG ADR)', 'value': 'FPRUY'},
#  {'label': 'FKWL (Franklin Wireless Corp.)', 'value': 'FKWL'},
#  {'label': 'FSP (Franklin Street Properties Corp.)', 'value': 'FSP'},
#  {'label': 'FJTSF (Fujitsu Ltd.)', 'value': 'FJTSF'},
#  {'label': 'GSQB (G Squared Ascend II Inc. Cl A)', 'value': 'GSQB'},
#  {'label': 'GSQB.UT (G Squared Ascend II Inc.)', 'value': 'GSQB.UT'},
#  {'label': 'GSQD.WT (G Squared Ascend I Inc. Wt)', 'value': 'GSQD.WT'},
#  {'label': 'GSQD (G Squared Ascend I Inc. Cl A)', 'value': 'GSQD'},
#  {'label': 'GSQD.UT (G Squared Ascend I Inc.)', 'value': 'GSQD.UT'},
#  {'label': 'KANAF (G Mining Ventures Corp.)', 'value': 'KANAF'},
#  {'label': 'GMVDW (G Medical Innovations Holdings Ltd. Wt)', 'value': 'GMVDW'},
#  {'label': 'GMVD (G Medical Innovations Holdings Ltd.)', 'value': 'GMVD'},
#  {'label': 'FVCB (FVCBankcorp Inc.)', 'value': 'FVCB'},
#  {'label': 'FYGGY (Fuyao Glass Industry Group Co. Ltd. ADR)',
#   'value': 'FYGGY'},
#  {'label': 'FFHL (Fuwei Films (Holdings) Co. Ltd.)', 'value': 'FFHL'},
#  {'label': 'FTRS (Futuris Co.)', 'value': 'FTRS'},
#  {'label': 'FUTL (FutureLand Corp.)', 'value': 'FUTL'},
#  {'label': 'FF (FutureFuel Corp.)', 'value': 'FF'},
#  {'label': 'FUTS (Future Science Holdings Inc.)', 'value': 'FUTS'},
#  {'label': 'GHACU (Gaming & Hospitality Acquisition Corp.)', 'value': 'GHACU'},
#  {'label': 'GNRD (General DataComm Industries Inc.)', 'value': 'GNRD'},
#  {'label': 'CANN (General Cannabis Corp.)', 'value': 'CANN'},
#  {'label': 'GNRC (Generac Holdings Inc.)', 'value': 'GNRC'},
#  {'label': 'GAM.PRB (General American Investors Co. Inc. 5.95% Cum. Pfd. Series B $1 par value)',
#   'value': 'GAM.PRB'},
#  {'label': 'GEGYY (Genel Energy PLC ADR)', 'value': 'GEGYY'},
#  {'label': 'GEGYF (Genel Energy PLC)', 'value': 'GEGYF'},
#  {'label': 'GENC (Gencor Industries Inc.)', 'value': 'GENC'},
#  {'label': 'GNK (Genco Shipping & Trading Ltd.)', 'value': 'GNK'},
#  {'label': 'GNCC (Genco Corp.)', 'value': 'GNCC'},
#  {'label': 'GNSS (Genasys Inc.)', 'value': 'GNSS'},
#  {'label': 'GNCLF (Gencell Ltd.)', 'value': 'GNCLF'},
#  {'label': 'MNIZ (Gen 2 Technologies Inc.)', 'value': 'MNIZ'},
#  {'label': 'GMZP (GEMZ Corp.)', 'value': 'GMZP'},
#  {'label': 'GEMZ (GEMXX Corp.)', 'value': 'GEMZ'},
#  {'label': 'GMTX (Gemini Therapeutics Inc.)', 'value': 'GMTX'},
#  {'label': 'GGMC (Glenfarne Merger Corp. Cl A)', 'value': 'GGMC'},
#  {'label': 'GOCOF (Go Metals Corp.)', 'value': 'GOCOF'},
#  {'label': 'GROY (Gold Royalty Corp.)', 'value': 'GROY'},
#  {'label': 'GRHI (Gold Rock Holdings Inc. Cl A)', 'value': 'GRHI'},
#  {'label': 'ELKMF (Gold Road Resources Ltd.)', 'value': 'ELKMF'},
#  {'label': 'GRPS (Gold River Productions Inc.)', 'value': 'GRPS'},
#  {'label': 'GORO (Gold Resource Corp.)', 'value': 'GORO'},
#  {'label': 'GDRZF (Gold Reserve Inc. Cl A)', 'value': 'GDRZF'},
#  {'label': 'GPOTF (Gold Port Corp.)', 'value': 'GPOTF'},
#  {'label': 'GMTNF (Gold Mountain Mining Corp.)', 'value': 'GMTNF'},
#  {'label': 'GLIOF (Gold Lion Resources Inc.)', 'value': 'GLIOF'},
#  {'label': 'TLLZF (Gold Line Resources Ltd.)', 'value': 'TLLZF'},
#  {'label': 'GFI (Gold Fields Ltd. ADR)', 'value': 'GFI'},
#  {'label': 'GFIOF (Gold Fields Ltd.)', 'value': 'GFIOF'},
#  {'label': 'GEGP (Gold Entertainment Group Inc.)', 'value': 'GEGP'},
#  {'label': 'GBRCF (Gold Bull Resources Corp.)', 'value': 'GBRCF'},
#  {'label': 'GRPH (Graphite Bio Inc.)', 'value': 'GRPH'},
#  {'label': 'GPK (Graphic Packaging Holding Co.)', 'value': 'GPK'},
#  {'label': 'GMGMF (Graphene Manufacturing Group Ltd.)', 'value': 'GMGMF'},
#  {'label': 'GSTX (Graphene & Solar Technologies Ltd.)', 'value': 'GSTX'},
#  {'label': 'GELEF (Graphano Energy Ltd.)', 'value': 'GELEF'},
#  {'label': 'REGRF (Graph Blockchain Inc.)', 'value': 'REGRF'},
#  {'label': 'GPFT (Grapefruit USA Inc.)', 'value': 'GPFT'},
#  {'label': 'GRP.UT (Granite REIT Inc.)', 'value': 'GRP.UT'},
#  {'label': 'GPMT (Granite Point Mortgage Trust Inc.)', 'value': 'GPMT'},
#  {'label': 'GCXXF (Granite Creek Copper Ltd.)', 'value': 'GCXXF'},
#  {'label': 'GVA (Granite Construction Inc.)', 'value': 'GVA'},
#  {'label': 'GCFB (Granite City Food & Brewery Ltd.)', 'value': 'GCFB'},
#  {'label': 'GRRBP (GrandSouth Bancorp Pfd. Series A)', 'value': 'GRRBP'},
#  {'label': 'GRRB (GrandSouth Bancorp)', 'value': 'GRRB'},
#  {'label': 'GPTRF (Grande Portage Resources Ltd.)', 'value': 'GPTRF'},
#  {'label': 'GPAEF (Grupo Aeroportuario del Pacifico S.A.B. de C.V. Series B)',
#   'value': 'GPAEF'},
#  {'label': 'PAC (Grupo Aeroportuario del Pacifico S.A.B. de C.V. ADR)',
#   'value': 'PAC'},
#  {'label': 'HLAGF (Hapag-Lloyd AG)', 'value': 'HLAGF'},
#  {'label': 'THG (Hanover Insurance Group Inc.)', 'value': 'THG'},
#  {'label': 'HNFSA (Hanover Foods Corp. Cl A)', 'value': 'HNFSA'},
#  {'label': 'HVRRY (Hannover Rueck SE ADR)', 'value': 'HVRRY'},
#  {'label': 'HVRRF (Hannover Rueck SE)', 'value': 'HVRRF'},
#  {'label': 'HHSE (Hannover House Inc.)', 'value': 'HHSE'},
#  {'label': 'HASI (Hannon Armstrong Sustainable Infrastructure Capital Inc.)',
#   'value': 'HASI'},
#  {'label': 'HANNF (Hannan Metals Ltd.)', 'value': 'HANNF'},
#  {'label': 'HAFC (Hanmi Financial Corp.)', 'value': 'HAFC'},
#  {'label': 'PHJMF (Hanjaya Mandala Sampoerna)', 'value': 'PHJMF'},
#  {'label': 'HNGR (Hanger Inc.)', 'value': 'HNGR'},
#  {'label': 'HSNGY (Hang Seng Bank Ltd. ADR)', 'value': 'HSNGY'},
#  {'label': 'HLPPY (Hang Lung Properties Ltd. ADR)', 'value': 'HLPPY'},
#  {'label': 'HLPPF (Hang Lung Properties Ltd.)', 'value': 'HLPPF'},
#  {'label': 'HLKHF (Hella KGaA Hueck & Co.)', 'value': 'HLKHF'},
#  {'label': 'HLLGY (HELLA GmbH & Co. KGaA ADR)', 'value': 'HLLGY'},
#  {'label': 'HLXW (Helix Wind Corp.)', 'value': 'HLXW'},
#  {'label': 'HLX (Helix Energy Solutions Group Inc.)', 'value': 'HLX'},
#  {'label': 'HBPCF (Helix BioPharma Corp.)', 'value': 'HBPCF'},
#  {'label': 'HSDT (Helius Medical Technologies Inc.)', 'value': 'HSDT'},
#  {'label': 'HLXA (Helix Acquisition Corp. Cl A)', 'value': 'HLXA'},
#  {'label': 'HLOGF (Helium One Group Ltd.)', 'value': 'HLOGF'},
#  {'label': 'HSTXF (Heliostar Metals Ltd.)', 'value': 'HSTXF'},
#  {'label': 'HLIO (Helios Technologies Inc.)', 'value': 'HLIO'},
#  {'label': 'FFXXF (Helios Fairfax Partners Corp.)', 'value': 'FFXXF'},
#  {'label': 'HMNY (Helios & Matheson Analytics Inc.)', 'value': 'HMNY'},
#  {'label': 'HELE (Helen of Troy Ltd.)', 'value': 'HELE'},
#  {'label': 'HLBZW (Helbiz Inc. Wt)', 'value': 'HLBZW'},
#  {'label': 'HLBZ (Helbiz Inc.)', 'value': 'HLBZ'},
#  {'label': 'HMCTF (HNA Infrastructure Co. Ltd.)', 'value': 'HMCTF'},
#  {'label': 'HUMRF (Hummingbird Resources PLC)', 'value': 'HUMRF'},
#  {'label': 'HTHL (Humitech International Group Inc.)', 'value': 'HTHL'},
#  {'label': 'HUML (Humble Energy Inc.)', 'value': 'HUML'},
#  {'label': 'HMBL (HUMBL Inc.)', 'value': 'HMBL'},
#  {'label': 'HUMT (Humatech Inc.)', 'value': 'HUMT'},
#  {'label': 'HGEN (Humanigen Inc.)', 'value': 'HGEN'},
#  {'label': 'HMCOW (HumanCo Acquisition Corp. Wt)', 'value': 'HMCOW'},
#  {'label': 'HMCO (HumanCo Acquisition Corp. Cl A)', 'value': 'HMCO'},
#  {'label': 'HMCOU (HumanCo Acquisition Corp.)', 'value': 'HMCOU'},
#  {'label': 'HUM (Humana Inc.)', 'value': 'HUM'},
#  {'label': 'HMNU (Human Unitec International Inc.)', 'value': 'HMNU'},
#  {'label': 'HUMAW (Humacyte Inc. Wt)', 'value': 'HUMAW'},
#  {'label': 'HUMA (Humacyte Inc.)', 'value': 'HUMA'},
#  {'label': 'HULCF (Hulic Co. Ltd.)', 'value': 'HULCF'},
#  {'label': 'HUIZ (Huize Holding Ltd. ADR)', 'value': 'HUIZ'},
#  {'label': 'IIVIP (II-VI Inc. 6% Pfd.)', 'value': 'IIVIP'},
#  {'label': 'IIVI (II-VI Inc.)', 'value': 'IIVI'},
#  {'label': 'ITOX (IIOT-OXYS Inc.)', 'value': 'ITOX'},
#  {'label': 'IH (iHuman Inc. ADR)', 'value': 'IH'},
#  {'label': 'INFO (IHS Markit Ltd.)', 'value': 'INFO'},
#  {'label': 'IHS (IHS Holding Ltd.)', 'value': 'IHS'},
#  {'label': 'IHICY (IHI Corp. ADR)', 'value': 'IHICY'},
#  {'label': 'IHRT (iHeartMedia Inc.)', 'value': 'IHRT'},
#  {'label': 'IGSC (IGS Capital Group Ltd.)', 'value': 'IGSC'},
#  {'label': 'IIDDY (IGO Ltd. ADR)', 'value': 'IIDDY'},
#  {'label': 'IGNYW (Ignyte Acquisition Corp. Wt)', 'value': 'IGNYW'},
#  {'label': 'IGNY (Ignyte Acquisition Corp.)', 'value': 'IGNY'},
#  {'label': 'IGNYU (Ignyte Acquisition Corp.)', 'value': 'IGNYU'},
#  {'label': 'BILZF (Ignite International Brands Ltd.)', 'value': 'BILZF'},
#  {'label': 'IGPG (Ignis Petroleum Group Inc.)', 'value': 'IGPG'},
#  {'label': 'IAIC (Information Analysis Inc.)', 'value': 'IAIC'},
#  {'label': 'INFA (Informatica Inc.)', 'value': 'INFA'},
#  {'label': 'LINK (Interlink Electronics Inc.)', 'value': 'LINK'},
#  {'label': 'INIS (International Isotopes Inc.)', 'value': 'INIS'},
#  {'label': 'MFMLF (International Iconic Gold Exploration Corp.)',
#   'value': 'MFMLF'},
#  {'label': 'IGICW (International General Insurance Holdings Ltd. Wt)',
#   'value': 'IGICW'},
#  {'label': 'IGIC (International General Insurance Holdings Ltd.)',
#   'value': 'IGIC'},
#  {'label': 'IGT (International Game Technology PLC)', 'value': 'IGT'},
#  {'label': 'IFF (International Flavors & Fragrances Inc.)', 'value': 'IFF'},
#  {'label': 'IDVV (International Endeavors Corp.)', 'value': 'IDVV'},
#  {'label': 'IDND (International Dispensing Corp.)', 'value': 'IDND'},
#  {'label': 'IDIG (International Digital Holding Inc.)', 'value': 'IDIG'},
#  {'label': 'ICTEF (International Container Terminal Services Inc.)',
#   'value': 'ICTEF'},
#  {'label': 'ICAGY (International Consolidated Airlines Group S.A. ADR)',
#   'value': 'ICAGY'},
#  {'label': 'BABWF (International Consolidated Airlines Group S.A.)',
#   'value': 'BABWF'},
#  {'label': 'ISON (Isonics Corp.)', 'value': 'ISON'},
#  {'label': 'IOMT (Isomet Corp.)', 'value': 'IOMT'},
#  {'label': 'ISENF (IsoEnergy Ltd.)', 'value': 'ISENF'},
#  {'label': 'ISOLF (Isodiol International Inc.)', 'value': 'ISOLF'},
#  {'label': 'ISLEW (Isleworth Healthcare Acquisition Corp. Wt)',
#   'value': 'ISLEW'},
#  {'label': 'ISLE (Isleworth Healthcare Acquisition Corp.)', 'value': 'ISLE'},
#  {'label': 'ISGN (iSign Solutions Inc.)', 'value': 'ISGN'},
#  {'label': 'ISDSF (iSign Media Solutions Inc.)', 'value': 'ISDSF'},
#  {'label': 'ISBA (Isabella Bank Corp.)', 'value': 'ISBA'},
#  {'label': 'IWINF (Irwin Naturals Inc.)', 'value': 'IWINF'},
#  {'label': 'IRVRF (Irving Resources Inc.)', 'value': 'IRVRF'},
#  {'label': 'IRS.WT (IRSA-Inversiones y Representaciones S.A. Wt)',
#   'value': 'IRS.WT'},
#  {'label': 'IRS (IRSA-Inversiones y Representaciones S.A. GDR)',
#   'value': 'IRS'},
#  {'label': 'IRCP (IRSA Propiedades Comerciales S.A. ADR)', 'value': 'IRCP'},
#  {'label': 'JRONF (Jeronimo Martins SGPS S/A)', 'value': 'JRONF'},
#  {'label': 'JROOF (Jericho Energy Ventures Inc.)', 'value': 'JROOF'},
#  {'label': 'KRT (Karat Packaging Inc.)', 'value': 'KRT'},
#  {'label': 'KAR (KAR Auction Services Inc.)', 'value': 'KAR'},
#  {'label': 'KAOOY (Kao Corp. ADR)', 'value': 'KAOOY'},
#  {'label': 'KAOCF (Kao Corp.)', 'value': 'KAOCF'},
#  {'label': 'BZ (Kanzhun Ltd. ADR)', 'value': 'BZ'},
#  {'label': 'KSU.PR (Kansas City Southern 4% Non-Cum Pfd.)', 'value': 'KSU.PR'},
#  {'label': 'KSU (Kansas City Southern)', 'value': 'KSU'},
#  {'label': 'KCLI (Kansas City Life Insurance Co.)', 'value': 'KCLI'},
#  {'label': 'KPTCY (Kansai Paint Co. Ltd. ADR)', 'value': 'KPTCY'},
#  {'label': 'KSANF (Kansai Paint Co. Ltd.)', 'value': 'KSANF'},
#  {'label': 'KAEPY (Kansai Electric Power Co. Inc. ADR)', 'value': 'KAEPY'},
#  {'label': 'KNBIF (Kane Biotech Inc.)', 'value': 'KNBIF'},
#  {'label': 'KNDI (Kandi Technologies Group Inc.)', 'value': 'KNDI'},
#  {'label': 'KMBIF (Kambi Group PLC Series B)', 'value': 'KMBIF'},
#  {'label': 'KIGRY (Kion Group AG ADR)', 'value': 'KIGRY'},
#  {'label': 'KNNGF (Kion Group AG)', 'value': 'KNNGF'},
#  {'label': 'DMPWW (Kintara Therapeutics Inc. Wt)', 'value': 'DMPWW'},
#  {'label': 'KUYAF (Kuya Silver Corp.)', 'value': 'KUYAF'},
#  {'label': 'KTWIY (Kurita Water Industries Ltd. ADR)', 'value': 'KTWIY'},
#  {'label': 'KCCFF (Kutcho Copper Corp.)', 'value': 'KCCFF'},
#  {'label': 'KTWIF (Kurita Water Industries Ltd.)', 'value': 'KTWIF'},
#  {'label': 'KURRY (Kuraray Co. Ltd. ADR)', 'value': 'KURRY'},
#  {'label': 'KRUS (Kura Sushi USA Inc.)', 'value': 'KRUS'},
#  {'label': 'KURA (Kura Oncology Inc.)', 'value': 'KURA'},
#  {'label': 'KLYCY (Kunlun Energy Co. Ltd. ADR)', 'value': 'KLYCY'},
#  {'label': 'KUNUF (Kunlun Energy Co. Ltd.)', 'value': 'KUNUF'},
#  {'label': 'KIROY (Kumba Iron Ore Ltd. ADR)', 'value': 'KIROY'},
#  {'label': 'KUMBF (Kumba Iron Ore Ltd.)', 'value': 'KUMBF'},
#  {'label': 'KULR (KULR Technology Group Inc.)', 'value': 'KULR'},
#  {'label': 'KLIC (Kulicke & Soffa Industries Inc.)', 'value': 'KLIC'},
#  {'label': 'LOGL (Legend Oil & Gas Ltd.)', 'value': 'LOGL'},
#  {'label': 'LEGN (Legend Biotech Corp. ADR)', 'value': 'LEGN'},
#  {'label': 'LGTOU (Legato Merger II)', 'value': 'LGTOU'},
#  {'label': 'LZ (LegalZoom.com Inc.)', 'value': 'LZ'},
#  {'label': 'LGGNY (Legal & General Group PLC ADR)', 'value': 'LGGNY'},
#  {'label': 'LGGNF (Legal & General Group PLC)', 'value': 'LGGNF'},
#  {'label': 'LEGX (LegacyXChange Inc.)', 'value': 'LEGX'},
#  {'label': 'LGYV (Legacy Ventures International Inc.)', 'value': 'LGYV'},
#  {'label': 'LEGH (Legacy Housing Corp.)', 'value': 'LEGH'},
#  {'label': 'LEAI (Legacy Education Alliance Inc.)', 'value': 'LEAI'},
#  {'label': 'LEGIF (LEG Immobilien SE)', 'value': 'LEGIF'},
#  {'label': 'LFTRW (Lefteris Acquisition Corp. Wt)', 'value': 'LFTRW'},
#  {'label': 'LFTR (Lefteris Acquisition Corp. Cl A)', 'value': 'LFTR'},
#  {'label': 'LFTRU (Lefteris Acquisition Corp.)', 'value': 'LFTRU'},
#  {'label': 'LPTH (Lightpath Technologies Inc. Cl A)', 'value': 'LPTH'},
#  {'label': 'ZEV.WT (Lightning eMotors Inc. Wt)', 'value': 'ZEV.WT'},
#  {'label': 'LBTD (Lotus Bio-Technology Development Corp.)', 'value': 'LBTD'},
#  {'label': 'LOTBY (Lotus Bakeries N.V. ADR)', 'value': 'LOTBY'},
#  {'label': 'LTTGF (LottoGopher Holdings Inc.)', 'value': 'LTTGF'},
#  {'label': 'LTRYW (Lottery.com Inc. Wt)', 'value': 'LTRYW'},
#  {'label': 'LTRY (Lottery.com Inc.)', 'value': 'LTRY'},
#  {'label': 'LOTE (Lot78 Inc.)', 'value': 'LOTE'},
#  {'label': 'LSANF (Los Andes Copper Ltd.)', 'value': 'LSANF'},
#  {'label': "LRLCY (L'Oreal S.A. ADR)", 'value': 'LRLCY'},
#  {'label': "LRLCF (L'Oreal S.A.)", 'value': 'LRLCF'},
#  {'label': 'RIDE (Lordstown Motors Corp.)', 'value': 'RIDE'},
#  {'label': 'LORL (Loral Space & Communications Inc.)', 'value': 'LORL'},
#  {'label': 'LPTV (Loop Media Inc.)', 'value': 'LPTV'},
#  {'label': 'LOOP (Loop Industries Inc.)', 'value': 'LOOP'},
#  {'label': 'LOIMY (Loomis AB ADR)', 'value': 'LOIMY'},
#  {'label': 'MEQYF (Mainstreet Equity Corp.)', 'value': 'MEQYF'},
#  {'label': 'MNSB (MainStreet Bancshares Inc.)', 'value': 'MNSB'},
#  {'label': 'MTDR (Matador Resources Co.)', 'value': 'MTDR'},
#  {'label': 'MZZMF (Matador Mining Ltd.)', 'value': 'MZZMF'},
#  {'label': 'MMND (Mastermind Inc.)', 'value': 'MMND'},
#  {'label': 'MCFT (MasterCraft Boat Holdings Inc.)', 'value': 'MCFT'},
#  {'label': 'MA (Mastercard Inc.)', 'value': 'MA'},
#  {'label': 'MSTO (Masterbeat Corp.)', 'value': 'MSTO'},
#  {'label': 'MHH (Mastech Digital Inc.)', 'value': 'MHH'},
#  {'label': 'MTZ (MasTec Inc.)', 'value': 'MTZ'},
#  {'label': 'MSRT (Massroots Inc.)', 'value': 'MSRT'},
#  {'label': 'MMRTY (Massmart Holdings Ltd. ADR)', 'value': 'MMRTY'},
#  {'label': 'MMMW (Mass Megawatts Wind Power Inc.)', 'value': 'MMMW'},
#  {'label': 'DOOR (Masonite International Corp.)', 'value': 'DOOR'},
#  {'label': 'MIT.WT (Mason Industrial Technology Inc. Wt)', 'value': 'MIT.WT'},
#  {'label': 'MIT (Mason Industrial Technology Inc. Cl A)', 'value': 'MIT'},
#  {'label': 'MEIP (MEI Pharma Inc.)', 'value': 'MEIP'},
#  {'label': 'NSAUF (MegumaGold Corp.)', 'value': 'NSAUF'},
#  {'label': 'MGON (Megola Inc.)', 'value': 'MGON'},
#  {'label': 'MEGGY (Meggitt PLC ADR)', 'value': 'MEGGY'},
#  {'label': 'MEGGF (Meggitt PLC)', 'value': 'MEGGF'},
#  {'label': 'MGAWY (MegaWorld Corp. ADR)', 'value': 'MGAWY'},
#  {'label': 'WALRF (MegaWatt Lithium & Battery Metals Corp.)',
#   'value': 'WALRF'},
#  {'label': 'MGNT (Meganet Corp.)', 'value': 'MGNT'},
#  {'label': 'MHSDF (Megacable Holdings S.A.B. de C.V. Series CPO)',
#   'value': 'MHSDF'},
# ...
#   'value': 'NRUC'},
#  {'label': 'NNN (National Retail Properties Inc.)', 'value': 'NNN'},
#  {'label': 'NRC (National Research Corp.)', 'value': 'NRC'},
#  {'label': 'NPK (National Presto Industries Inc.)', 'value': 'NPK'},
#  {'label': 'NATI (National Instruments Corp.)', 'value': 'NATI'},
#  {'label': 'NHLG (National Healthcare Logistics Inc.)', 'value': 'NHLG'},
#  {'label': 'NWSTF (New Standard Energy Ltd.)', 'value': 'NWSTF'},
#  {'label': 'NSLPQ (New Source Energy Partners L.P.)', 'value': 'NSLPQ'},
#  {'label': 'NRZ.PRA (New Residential Investment Corp. 7.5% Fixed-to-Floating Pfd. Series A)',
#   'value': 'NRZ.PRA'},
#  {'label': 'NRZ.PRB (New Residential Investment Corp. 7.125% Series B Fixed-to-Floating Rate Cum. Redeem. Pfd.)',
#   'value': 'NRZ.PRB'},
#  {'label': 'NRZ.PRD (New Residential Investment Corp. 7.00% Fixed-Rate Cum. Redeem. Pfd. Series D)',
#   'value': 'NRZ.PRD'},
#  {'label': 'NRZ.PRC (New Residential Investment Corp. 6.375% Pfd. Series C)',
#   'value': 'NRZ.PRC'},
#  {'label': 'NRZ (New Residential Investment Corp.)', 'value': 'NRZ'},
#  {'label': 'NEWR (New Relic Inc.)', 'value': 'NEWR'},
#  {'label': 'NPABU (New Providence Acquisition Corp. II)', 'value': 'NPABU'},
#  {'label': 'NPDCF (New Placer Dome Gold Corp.)', 'value': 'NPDCF'},
#  {'label': 'NWPP (New Peoples Bankshares Inc.)', 'value': 'NWPP'},
#  {'label': 'NEWP (New Pacific Metals Corp.)', 'value': 'NEWP'},
#  {'label': 'EDU (New Oriental Education & Technology Group Inc. ADR)',
#   'value': 'EDU'},
#  {'label': 'NTDOF (Nintendo Co. Ltd.)', 'value': 'NTDOF'},
#  {'label': 'NINE (Nine Energy Service Inc.)', 'value': 'NINE'},
#  {'label': 'NDGPY (Nine Dragons Paper Holdings Ltd. ADR)', 'value': 'NDGPY'},
#  {'label': 'NSTD.WT (Northern Star Investment Corp. IV Wt)',
#   'value': 'NSTD.WT'},
#  {'label': 'NSTD (Northern Star Investment Corp. IV Cl A)', 'value': 'NSTD'},
#  {'label': 'NSTD.UT (Northern Star Investment Corp. IV)', 'value': 'NSTD.UT'},
#  {'label': 'NSTC.WT (Northern Star Investment Corp. III Wt)',
#   'value': 'NSTC.WT'},
#  {'label': 'NSTC (Northern Star Investment Corp. III Cl A)', 'value': 'NSTC'},
#  {'label': 'NSTC.UT (Northern Star Investment Corp. III)', 'value': 'NSTC.UT'},
#  {'label': 'NSTB.WT (Northern Star Investment Corp. II Wt)',
#   'value': 'NSTB.WT'},
#  {'label': 'NSTB (Northern Star Investment Corp. II Cl A)', 'value': 'NSTB'},
#  {'label': 'NSTB.UT (Northern Star Investment Corp. II)', 'value': 'NSTB.UT'},
#  {'label': 'NSMCF (Northern Sphere Mining Corp.)', 'value': 'NSMCF'},
#  {'label': 'NSHRF (Northern Shield Resources Inc.)', 'value': 'NSHRF'},
#  {'label': 'NRTHF (Northern Power Systems Corp.)', 'value': 'NRTHF'},
#  {'label': 'NOG (Northern Oil & Gas Inc.)', 'value': 'NOG'},
#  {'label': 'NMEX (Northern Minerals & Exploration Ltd.)', 'value': 'NMEX'},
#  {'label': 'NXPI (NXP Semiconductors N.V.)', 'value': 'NXPI'},
#  {'label': 'NXGB (NxGen Brands Inc.)', 'value': 'NXGB'},
#  {'label': 'OTLC (Oncotelic Therapeutics Inc.)', 'value': 'OTLC'},
#  {'label': 'ONCS (OncoSec Medical Inc.)', 'value': 'ONCS'},
#  {'label': 'ONCR (Oncorus Inc.)', 'value': 'ONCR'},
#  {'label': 'ONTX (Onconova Therapeutics Inc.)', 'value': 'ONTX'},
#  {'label': 'ONCY (Oncolytics Biotech Inc.)', 'value': 'ONCY'},
#  {'label': 'ONPH (Oncology Pharma Inc.)', 'value': 'ONPH'},
#  {'label': 'OCLG (Oncologix Tech Inc.)', 'value': 'OCLG'},
#  {'label': 'OCX (Oncocyte Corp.)', 'value': 'OCX'},
#  {'label': 'OBMP (OncBioMune Pharmaceuticals Inc.)', 'value': 'OBMP'},
#  {'label': 'ONSS (Onassis Holdings Corp.)', 'value': 'ONSS'},
#  {'label': 'ONCI (On4 Communications Inc.)', 'value': 'ONCI'},
#  {'label': 'ONTF (ON24 Inc.)', 'value': 'ONTF'},
#  {'label': 'OTIVF (On Track Innovations Ltd.)', 'value': 'OTIVF'},
#  {'label': 'ON (ON Semiconductor Corp.)', 'value': 'ON'},
#  {'label': 'KIDS (OrthoPediatrics Corp.)', 'value': 'KIDS'},
#  {'label': 'OFIX (Orthofix Medical Inc.)', 'value': 'OFIX'},
#  {'label': 'ORTIF (Ortho Regenerative Technologies Inc.)', 'value': 'ORTIF'},
#  {'label': 'OCDX (Ortho Clinical Diagnostics Holdings PLC)', 'value': 'OCDX'},
#  {'label': 'ORSUF (Orsu Metals Corp.)', 'value': 'ORSUF'},
#  {'label': 'ORRF (Orrstown Financial Services Inc.)', 'value': 'ORRF'},
#  {'label': 'PLFF (Orpheum Property Inc.)', 'value': 'PLFF'},
#  {'label': 'ORPH (Orphazyme A/S ADR)', 'value': 'ORPH'},
#  {'label': 'OZYMF (Orphazyme A/S)', 'value': 'OZYMF'},
#  {'label': 'ORPEF (Orpea S.A.)', 'value': 'ORPEF'},
#  {'label': 'OROXF (Orosur Mining Inc.)', 'value': 'OROXF'},
#  {'label': 'OGNRF (Orogen Royalties Inc.)', 'value': 'OGNRF'},
#  {'label': 'PLMR (Palomar Holdings Inc.)', 'value': 'PLMR'},
#  {'label': 'PANW (Palo Alto Networks Inc.)', 'value': 'PANW'},
#  {'label': 'PTTTS (Palmetto Real Estate Trust SBI)', 'value': 'PTTTS'},
#  {'label': 'PLLVF (Palladon Ventures Ltd.)', 'value': 'PLLVF'},
#  {'label': 'PEB (Pebblebrook Hotel Trust)', 'value': 'PEB'},
#  {'label': 'PSO (Pearson PLC ADR)', 'value': 'PSO'},
#  {'label': 'PSORF (Pearson PLC)', 'value': 'PSORF'},
#  {'label': 'PGC (Peapack-Gladstone Financial Corp.)', 'value': 'PGC'},
#  {'label': 'PKBFF (Peakbirch Logic Inc.)', 'value': 'PKBFF'},
#  {'label': 'PKREF (Peak Resources Ltd.)', 'value': 'PKREF'},
#  {'label': 'PKPH (Peak Pharmaceuticals Inc.)', 'value': 'PKPH'},
#  {'label': 'HEGLF (Peak Minerals Ltd.)', 'value': 'HEGLF'},
#  {'label': 'IDFB (Peak Bancorp Inc.)', 'value': 'IDFB'},
#  {'label': 'BTU (Peabody Energy Corp.)', 'value': 'BTU'},
#  {'label': 'PDSB (PDS Biotechnology Corp.)', 'value': 'PDSB'},
#  {'label': 'PDLB (PDL Community Bancorp)', 'value': 'PDLB'},
#  {'label': 'PDFS (PDF Solutions Inc.)', 'value': 'PDFS'},
#  {'label': 'PDCE (PDC Energy Inc.)', 'value': 'PDCE'},
#  {'label': 'ROTH (PharmaRoth Labs Inc.)', 'value': 'ROTH'},
#  {'label': 'PHBI (Pharmagreen Biotech Inc.)', 'value': 'PHBI'},
#  {'label': 'PLUG (Plug Power Inc.)', 'value': 'PLUG'},
#  {'label': 'PLXS (Plexus Corp.)', 'value': 'PLXS'},
#  {'label': 'PLRX (Pliant Therapeutics Inc.)', 'value': 'PLRX'},
#  {'label': 'PHI (PLDT Inc. ADR)', 'value': 'PHI'},
#  {'label': 'PHTCF (PLDT Inc.)', 'value': 'PHTCF'},
#  {'label': 'PLBY (PLBY Group Inc.)', 'value': 'PLBY'},
#  {'label': 'PAZRF (Plaza Retail REIT)', 'value': 'PAZRF'},
#  {'label': 'PYTCF (Playtech PLC)', 'value': 'PYTCF'},
#  {'label': 'PYTCY (Playtech PLC ADR)', 'value': 'PYTCY'},
#  {'label': 'MYPSW (Playstudios Inc. Wt)', 'value': 'MYPSW'},
#  {'label': 'MYPS (Playstudios Inc.)', 'value': 'MYPS'},
#  {'label': 'PMTYF (Playmates Toys Ltd.)', 'value': 'PMTYF'},
#  {'label': 'PYHOF (Playmates Holdings Ltd.)', 'value': 'PYHOF'},
#  {'label': 'PINC (Premier Inc.)', 'value': 'PINC'},
#  {'label': 'PRRFY (Premier Foods PLC ADR)', 'value': 'PRRFY'},
#  {'label': 'PFC (Premier Financial Corp.)', 'value': 'PFC'},
#  {'label': 'PRXIQ (Premier Exhibitions Inc.)', 'value': 'PRXIQ'},
#  {'label': 'PRDGF (Premier Diversified Holdings Inc.)', 'value': 'PRDGF'},
#  {'label': 'PDIV (Premier Development & Investment Inc.)', 'value': 'PDIV'},
#  {'label': 'BIEI (Premier Biomedical Inc.)', 'value': 'BIEI'},
#  {'label': 'PRLD (Prelude Therapeutics Inc.)', 'value': 'PRLD'},
#  {'label': 'PLPC (Preformed Line Products Co.)', 'value': 'PLPC'},
#  {'label': 'OCBM (Preferred Commerce Inc.)', 'value': 'OCBM'},
#  {'label': 'BGAOY (Proximus Group ADR)', 'value': 'BGAOY'},
#  {'label': 'PFS (Provident Financial Services Inc.)', 'value': 'PFS'},
#  {'label': 'FPLPY (Provident Financial PLC ADR)', 'value': 'FPLPY'},
#  {'label': 'FPLPF (Provident Financial PLC)', 'value': 'FPLPF'},
#  {'label': 'PROV (Provident Financial Holdings Inc.)', 'value': 'PROV'},
#  {'label': 'PVBC (Provident Bancorp Inc.)', 'value': 'PVBC'},
#  {'label': 'QNTA (Quanta Inc.)', 'value': 'QNTA'},
#  {'label': 'NX (Quanex Building Products Corp.)', 'value': 'NX'},
#  {'label': 'QLYS (Qualys Inc.)', 'value': 'QLYS'},
#  {'label': 'XM (Qualtrics International Inc.)', 'value': 'XM'},
#  {'label': 'QBAK (Qualstar Corp.)', 'value': 'QBAK'},
#  {'label': 'QOEG (Quality Online Education Group Inc.)', 'value': 'QOEG'},
#  {'label': 'QUCOF (Qualitas Controladora S.A.B. de C.V.)', 'value': 'QUCOF'},
#  {'label': 'QLIS (Qualis Innovations Inc.)', 'value': 'QLIS'},
#  {'label': 'QLGN (Qualigen Therapeutics Inc.)', 'value': 'QLGN'},
#  {'label': 'QCOM (Qualcomm Inc.)', 'value': 'QCOM'},
#  {'label': 'QNTO (Quaint Oak Bancorp Inc.)', 'value': 'QNTO'},
#  {'label': 'KWR (Quaker Houghton)', 'value': 'KWR'},
#  {'label': 'RROYF (RE Royalties Ltd.)', 'value': 'RROYF'},
#  {'label': 'RDVA (RDVA Inc.)', 'value': 'RDVA'},
#  {'label': 'RSTN (RDE Inc.)', 'value': 'RSTN'},
#  {'label': 'RZSMF (RCS MediaGroup S.p.A.)', 'value': 'RZSMF'},
#  {'label': 'SOL (ReneSola Ltd. ADR)', 'value': 'SOL'},
#  {'label': 'RNECY (Renesas Electronics Corp. ADR)', 'value': 'RNECY'},
#  {'label': 'RNECF (Renesas Electronics Corp.)', 'value': 'RNECF'},
#  {'label': 'RGNNF (Renergen Ltd.)', 'value': 'RGNNF'},
#  {'label': 'RPHM (Reneo Pharmaceuticals Inc.)', 'value': 'RPHM'},
#  {'label': 'RIII (Renavotio Inc.)', 'value': 'RIII'},
#  {'label': 'RNLSY (Renault S.A. ADR)', 'value': 'RNLSY'},
#  {'label': 'RNSDF (Renault S.A.)', 'value': 'RNSDF'},
#  {'label': 'RNST (Renasant Corp.)', 'value': 'RNST'},
#  {'label': 'RNLX (Renalytix PLC ADR)', 'value': 'RNLX'},
#  {'label': 'RTNXF (Renalytix PLC)', 'value': 'RTNXF'},
#  {'label': 'RNR.PRG (RenaissanceRe Holdings Ltd. Dep. Pfd. (Rep. 1/1000th Share 4.2% Pfd. Series G))',
#   'value': 'RNR.PRG'},
#  {'label': 'RNR.PRF (RenaissanceRe Holdings Ltd. Dep. Pfd. (Rep. 1/1000th Non-Cum. Perp. Pfd. Series F))',
#   'value': 'RNR.PRF'},
#  {'label': 'RMPL.PR (RiverNorth Specialty Finance Corp. 5.875% Cum. Pfd. Series A)',
#   'value': 'RMPL.PR'},
#  {'label': 'RVCB (River Valley Community Bancorp)', 'value': 'RVCB'},
#  {'label': 'RCBC (River City Bank)', 'value': 'RCBC'},
#  {'label': 'RMBL (RumbleON Inc. Cl B)', 'value': 'RMBL'},
#  {'label': 'RTRFF (Rumble Resources Ltd.)', 'value': 'RTRFF'},
#  {'label': 'RUBY (Rubius Therapeutics Inc.)', 'value': 'RUBY'},
#  {'label': 'RBMNF (Rugby Mining Ltd.)', 'value': 'RBMNF'},
#  {'label': 'RBSFY (Rubis SCA ADR)', 'value': 'RBSFY'},
#  {'label': 'RBCN (Rubicon Technology Inc.)', 'value': 'RBCN'},
#  {'label': 'ROMJF (Rubicon Organics Inc.)', 'value': 'ROMJF'},
#  {'label': 'RUBLF (Rubellite Energy Inc.)', 'value': 'RUBLF'},
#  {'label': 'RGLXY (RTL Group S.A. ADR)', 'value': 'RGLXY'},
#  {'label': 'RRRT (R-Three Technologies Inc.)', 'value': 'RRRT'},
#  {'label': 'RTTGF (RTG Mining Inc.)', 'value': 'RTTGF'},
#  {'label': 'RTMFF (RT Minerals Corp.)', 'value': 'RTMFF'},
#  {'label': 'RRSFF (Rritual Superfoods Inc.)', 'value': 'RRSFF'},
#  {'label': 'SNYYF (Sany Heavy Equipment International Holdings Co. Ltd.)',
#   'value': 'SNYYF'},
#  {'label': 'SNWR (Sanwire Corp.)', 'value': 'SNWR'},
#  {'label': 'SNWV (SANUWAVE Health Inc.)', 'value': 'SNWV'},
#  {'label': 'SSLZY (Santos Ltd. ADR)', 'value': 'SSLZY'},
#  {'label': 'STOSF (Santos Ltd.)', 'value': 'STOSF'},
#  {'label': 'SANP (Santo Mining Corp.)', 'value': 'SANP'},
#  {'label': 'SPHDF (Santhera Pharmaceuticals Holding AG)', 'value': 'SPHDF'},
#  {'label': 'SANT (Santeon Group Inc.)', 'value': 'SANT'},
#  {'label': 'SNPHY (Santen Pharmaceutical Co. Ltd. ADR)', 'value': 'SNPHY'},
#  {'label': 'SNPHF (Santen Pharmaceutical Co. Ltd.)', 'value': 'SNPHF'},
#  {'label': 'SEBYF (SEB S.A.)', 'value': 'SEBYF'},
#  {'label': 'SEAS (SeaWorld Entertainment Inc.)', 'value': 'SEAS'},
#  {'label': 'SPNE (SeaSpine Holdings Corp.)', 'value': 'SPNE'},
#  {'label': 'SHLDQ (Sears Holdings Corp.)', 'value': 'SHLDQ'},
#  {'label': 'CNYCF (Searchlight Resources Inc.)', 'value': 'CNYCF'},
#  {'label': 'SRCH (Searchlight Minerals Corp.)', 'value': 'SRCH'},
#  {'label': 'SHQA (Shelter Acquisition Corp. I Cl A)', 'value': 'SHQA'},
#  {'label': 'SHQAU (Shelter Acquisition Corp. I)', 'value': 'SHQAU'},
#  {'label': 'SHLX (Shell Midstream Partners L.P.)', 'value': 'SHLX'},
#  {'label': 'SAWLF (ShawCor Ltd.)', 'value': 'SAWLF'},
#  {'label': 'SJR (Shaw Communications Inc. Cl B NV)', 'value': 'SJR'},
#  {'label': 'STTK (Shattuck Labs Inc.)', 'value': 'STTK'},
#  {'label': 'SMED (Sharps Compliance Corp.)', 'value': 'SMED'},
#  {'label': 'SBET (SharpLink Gaming Ltd.)', 'value': 'SBET'},
#  {'label': 'SHCAY (Sharp Corp. ADR)', 'value': 'SHCAY'},
#  {'label': 'SHRG (Sharing Services Global Corp.)', 'value': 'SHRG'},
#  {'label': 'SEII (Sharing Economy International Inc.)', 'value': 'SEII'},
#  {'label': 'SHCRW (Sharecare Inc. Wt)', 'value': 'SHCRW'},
#  {'label': 'SSNT (SilverSun Technologies Inc.)', 'value': 'SSNT'},
#  {'label': 'SSTRF (Silverstar Holdings Ltd.)', 'value': 'SSTRF'},
#  {'label': 'SLVRW (SilverSPAC Inc. Wt)', 'value': 'SLVRW'},
#  {'label': 'SLVR (SilverSPAC Inc. Cl A)', 'value': 'SLVR'},
#  {'label': 'SMTEF (Smart Eye AB)', 'value': 'SMTEF'},
#  {'label': 'SMEYF (Smart Employee Benefits Inc.)', 'value': 'SMEYF'},
#  {'label': 'SDEC (Smart Decision Inc.)', 'value': 'SDEC'},
#  {'label': 'ZSYC (Smart Closet Inc.)', 'value': 'ZSYC'},
#  {'label': 'SMKG (Smart Card Marketing Systems Inc.)', 'value': 'SMKG'},
#  {'label': 'SCNA (Smart Cannabis Corp.)', 'value': 'SCNA'},
#  {'label': 'DMTTF (Small Pharma Inc.)', 'value': 'DMTTF'},
#  {'label': 'SBDG (Small Business Development Group Inc.)', 'value': 'SBDG'},
#  {'label': 'SMTGY (SMA Solar Technology AG ADR)', 'value': 'SMTGY'},
#  {'label': 'SMTGF (SMA Solar Technology AG)', 'value': 'SMTGF'},
#  {'label': 'SMAA (SMA Alliance Inc.)', 'value': 'SMAA'},
#  {'label': 'SPHXF (SM Prime Holdings Inc.)', 'value': 'SPHXF'},
#  {'label': 'SVTMF (SM Investments Corp.)', 'value': 'SVTMF'},
#  {'label': 'SHC (Sotera Health Co.)', 'value': 'SHC'},
#  {'label': 'SOLTF (Sosei Group Corp.)', 'value': 'SOLTF'},
#  {'label': 'SOS (SOS Ltd. ADR)', 'value': 'SOS'},
#  {'label': 'SPSC (SPS Commerce Inc.)', 'value': 'SPSC'},
#  {'label': 'SRCGF (Spruce Ridge Resources Ltd.)', 'value': 'SRCGF'},
#  {'label': 'SPRB (Spruce Biosciences Inc.)', 'value': 'SPRB'},
#  {'label': 'SFM (Sprouts Farmers Market Inc.)', 'value': 'SFM'},
#  {'label': 'SRUTF (Sproutly Canada Inc.)', 'value': 'SRUTF'},
#  {'label': 'STHI (Sprout Tiny Homes Inc.)', 'value': 'STHI'},
#  {'label': 'SPT (Sprout Social Inc. Cl A)', 'value': 'SPT'},
#  {'label': 'SPAIF (Sprout AI Inc.)', 'value': 'SPAIF'},
#  {'label': 'SII (Sprott Inc.)', 'value': 'SII'},
#  {'label': 'CXM (Sprinklr Inc. Cl A)', 'value': 'CXM'},
#  {'label': 'SWTX (SpringWorks Therapeutics Inc.)', 'value': 'SWTX'},
#  {'label': 'SWSSW (Springwater Special Situations Corp. Wt)',
#   'value': 'SWSSW'},
#  {'label': 'SWSS (Springwater Special Situations Corp.)', 'value': 'SWSS'},
#  {'label': 'STON (StoneMor Inc.)', 'value': 'STON'},
#  {'label': 'STNE (StoneCo Ltd. Cl A)', 'value': 'STNE'},
#  {'label': 'SRCX (Stonebridge Resources Explorations Ltd.)', 'value': 'SRCX'},
#  {'label': 'APACW (StoneBridge Acquisition Corp. Wt)', 'value': 'APACW'},
#  {'label': 'APAC (StoneBridge Acquisition Corp. Cl A)', 'value': 'APAC'},
#  {'label': 'APACU (StoneBridge Acquisition Corp.)', 'value': 'APACU'},
#  {'label': 'SOIEF (Stolt-Nielsen Ltd.)', 'value': 'SOIEF'},
#  {'label': 'STOK (Stoke Therapeutics Inc.)', 'value': 'STOK'},
#  {'label': 'SYBT (Stock Yards Bancorp Inc.)', 'value': 'SYBT'},
#  {'label': 'STM (STMicroelectronics N.V.)', 'value': 'STM'},
#  {'label': 'SDGCF (Sundrug Co. Ltd.)', 'value': 'SDGCF'},
#  {'label': 'SUNW (Sunworks Inc.)', 'value': 'SUNW'},
#  {'label': 'SUWN (Sunwin Stevia International Inc.)', 'value': 'SUWN'},
#  {'label': 'SVLT (Sunvault Energy Inc.)', 'value': 'SVLT'},
#  {'label': 'STBFY (Suntory Beverage & Food Ltd. ADR)', 'value': 'STBFY'},
#  {'label': 'STBFF (Suntory Beverage & Food Ltd.)', 'value': 'STBFF'},
#  {'label': 'TWNI.WT (Tailwind International Acquisition Corp. Wt)',
#   'value': 'TWNI.WT'},
#  {'label': 'TWNI (Tailwind International Acquisition Corp. Cl A)',
#   'value': 'TWNI'},
#  {'label': 'TWND.WT (Tailwind Acquisition Corp. Wt)', 'value': 'TWND.WT'},
#  {'label': 'TWNI.UT (Tailwind International Acquisition Corp.)',
#   'value': 'TWNI.UT'},
#  {'label': 'TWND.UT (Tailwind Acquisition Corp. Un)', 'value': 'TWND.UT'},
#  {'label': 'TWND (Tailwind Acquisition Corp. Cl A)', 'value': 'TWND'},
#  {'label': 'THYCY (Taiheiyo Cement Corp. ADR)', 'value': 'THYCY'},
#  {'label': 'TAIMF (Taiga Motors Corp.)', 'value': 'TAIMF'},
#  ...]

# %%
df['Label'] = df['Ticker'] + " (" + df['Name'] + ")"
symbols = df['Ticker']
labels = df['Label']
df
# Out:
#       Ticker                            Name  \
# 0      ACAZF            Acadian Timber Corp.
# 1        AKR             Acadia Realty Trust
# 2       ACAD     ACADIA Pharmaceuticals Inc.
# 3       ACHC      Acadia Healthcare Co. Inc.
# 4        ASO  Academy Sports & Outdoors Inc.
# ...      ...                             ...
# 80584   TACO       Del Taco Restaurants Inc.
# 80585  PEFDF                       Defli Ltd
# 80586  DNCVF           Defiance Silver Corp.
# 80587  DEFTF          DeFi Technologies Inc.
# 80588   DFTC            Defentect Group Inc.
#
#                                       Label
# 0              ACAZF (Acadian Timber Corp.)
# 1                 AKR (Acadia Realty Trust)
# 2        ACAD (ACADIA Pharmaceuticals Inc.)
# 3         ACHC (Acadia Healthcare Co. Inc.)
# 4      ASO (Academy Sports & Outdoors Inc.)
# ...                                     ...
# 80584      TACO (Del Taco Restaurants Inc.)
# 80585                     PEFDF (Defli Ltd)
# 80586         DNCVF (Defiance Silver Corp.)
# 80587        DEFTF (DeFi Technologies Inc.)
# 80588           DFTC (Defentect Group Inc.)
#
# [80589 rows x 3 columns]

# %%
sltd_sec = 'AAPL'
# %%timeit
with db_session(engine) as session:
    stmt = select(Security.id, Security.ticker, Security.name).where(Security.ticker == sltd_sec).order_by(Security.ticker)
    result = session.execute(stmt)
    df = pd.DataFrame(result, columns = ['Sec_Id', 'Ticker', 'Name'])
df.tail()
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:SELECT security.id, security.ticker, security.name
# FROM security
# WHERE security.ticker = ? ORDER BY security.ticker
# INFO:sqlalchemy.engine.Engine:[cached since 220.5s ago] ('AAPL',)
# INFO:sqlalchemy.engine.Engine:ROLLBACK
#    Sec_Id Ticker                          Name
# 0   22758   AAPL  Leverage Shares 1X Apple ETP

# %%
# %%timeit
with db_session(engine) as session:
    result = session.execute(select(Security.ticker, Security.name).order_by(Security.ticker))
    df = pd.DataFrame(result, columns = ['Ticker', 'Name'])
df.tail()
# Out:
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:SELECT security.ticker, security.name
# FROM security ORDER BY security.ticker
# INFO:sqlalchemy.engine.Engine:[cached since 85.6s ago] ()
# INFO:sqlalchemy.engine.Engine:ROLLBACK
#       Ticker                                Name
# 80584  ZZE.H                Zidane Capital Corp.
# 80585   ZZMS                  Commerzbank AG ADR
# 80586    ZZZ  Sleep Country Canada Holdings Inc.
# 80587   ZZZD      BMO Tactical Dividend ETF Fund
# 80588  ZZZOF             Zinc One Resources Inc.

# %%
df.head()

# %%
with db_session(engine) as session:
    result = session.execute(select(Security.id, Security.ticker).order_by(Security.ticker))
    res = result.fetchone()
    print(res)
    # df = pd.DataFrame(result, columns = ['Sec_Id','Ticker'])
df.tail()

# %%
with db_session(engine) as session:
    # result = session.execute(select(Security.name, Country.name).join(Security.name).order_by(Security.id, Country.id))
    country = session.execute(select(Country).where(Country.name == "United States"))
    country = Country(name="United States")
    # country = session.query(Country).filter(Country.name=="United States")
    # print (country)
    print (country)
    result = session.execute(select(Security.ticker).where(Security.countries.contains(country)))
    df = pd.DataFrame(result)

# %%
sel_country = "United States"

with db_session(engine) as session:
    stmt = (select(Security.id, Security.ticker, Security.name).where(Security.countries.any(Country.name == sel_country)))
    by_country = session.execute(stmt).all()
    df = pd.DataFrame(by_country, columns = ['Sec_Id', 'Name', 'Ticker'])
print(df.Ticker.count())
df.tail()

# %%
sel_asset = "Stocks"

with db_session(engine) as session:
    stmt = (select(Security.id, Security.ticker, Security.name).where(Security.asset_class_id == (select(AssetClass.id).where(AssetClass.name == sel_asset))))
    by_asset = session.execute(stmt).all()
    df = pd.DataFrame(by_asset, columns = ['Sec_Id', 'Name', 'Ticker'])
print(df.Ticker.count())
df.tail()

# %%
sel_industry = "Software"

with db_session(engine) as session:
    stmt = (select(Security.id, Security.ticker, Security.name).where(Security.industries.any(Industry.name == sel_industry)))
    by_industry = session.execute(stmt).all()
    df = pd.DataFrame(by_industry, columns = ['Sec_Id', 'Name', 'Ticker'])
print(df.Ticker.count())
df.tail()
